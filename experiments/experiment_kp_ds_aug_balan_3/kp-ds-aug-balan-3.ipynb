# %%
import os

os.environ['TF_CPP_MIN_LOG_LEVEL'] = '2'

def check_and_install(package_name):
    try:
        __import__(package_name)
    except ImportError:
        os.system(f'pip install {package_name}')

check_and_install('gdown')

import matplotlib.pyplot as plt
import pathlib
from collections import defaultdict
import numpy as np
import pandas as pd
import seaborn as sns
from sklearn.metrics import confusion_matrix, classification_report

import tensorflow as tf
from tensorflow import keras
from keras.models import load_model
from tensorflow.keras import layers
from tensorflow.keras.regularizers import l2
from tensorflow.keras.initializers import HeUniform
from tensorflow.keras.callbacks import LearningRateScheduler, ModelCheckpoint, EarlyStopping

# %% [markdown]
# # Dataset visualization

# %%
def count_files_in_all_splits(dataset_path):
    """
    Counts the number of files in each class for the train, test, and valid directories.

    :param dataset_path: Path to the dataset (main directory).
    :return: Dictionary with the class name as the key and the number of files per split as values.
    """
    splits = ['train', 'test', 'valid']  # Main subdirectories
    class_counts = defaultdict(lambda: {'train': 0, 'test': 0, 'valid': 0})

    for split in splits:
        split_path = dataset_path / split
        if not split_path.exists():
            print(f"Subdirectory {split} not found in {dataset_path}")
            continue

        for class_name in os.listdir(split_path):
            class_path = split_path / class_name
            if class_path.is_dir():
                # Count the files in the class folder
                file_count = len([f for f in class_path.iterdir() if f.is_file()])
                class_counts[class_name][split] = file_count

    return class_counts

# Path to the dataset
dataset_path = pathlib.Path('kp_ds_aug_balan_3')  # Modify to the correct path

# Download and unzip the dataset, if necessary
if not dataset_path.exists():
    os.system('gdown 1l5pSCLQ55WLHzENXU__RrhXOigafms4P -O dataset_keypoints_yoga.zip') # Drive ID
    os.system('unzip -q dataset_keypoints_yoga.zip')

# Count files in each class
class_file_counts = count_files_in_all_splits(dataset_path)

# Map classes to numbered names
class_name_map = {cls: f"Class {i}" for i, cls in enumerate(class_file_counts)}

# Generate histograms for each split with classes sorted in descending order by file count
for split in ['train', 'test', 'valid']:
    # Sort classes alphabetically to get the mapping
    sorted_class_names = sorted(class_file_counts.keys())  # Alphabetical order
    class_name_map = {cls: f"Class {i}" for i, cls in enumerate(sorted_class_names)}  # Numeric mapping

    # Sort classes by the number of files in the current subset
    sorted_classes_by_count = sorted(class_file_counts.items(), key=lambda x: x[1][split], reverse=True)

    # Map labels to the format "Class X (real_name)"
    classes = [class_name_map[cls] for cls, _ in sorted_classes_by_count]
    file_counts = [counts[split] for _, counts in sorted_classes_by_count]

    # Generate the histogram
    plt.figure(figsize=(12, 6))
    plt.bar(classes, file_counts, edgecolor='black', alpha=0.7)
    plt.xlabel("Classes")
    plt.ylabel(f"Number of Files ({split.capitalize()})")
    plt.title(f"File Distribution by Class - {split.capitalize()}")
    plt.xticks(rotation=90)  # Rotate class names for better readability
    plt.tight_layout()  # Adjust layout to avoid overlap
    plt.show()

sorted_class_names = sorted(class_file_counts.keys())  # Sort real class names alphabetically
class_name_map = {cls: f"Class {i}" for i, cls in enumerate(sorted_class_names)}

# Display total counts with numbered and real names in alphabetical order
print("\nTotal count per class with numbered and real names (alphabetical order):")
for class_name in sorted_class_names:
    mapped_name = class_name_map[class_name]
    counts = class_file_counts[class_name]
    total = sum(counts.values())
    print(f"{mapped_name} ({class_name}): Train={counts['train']}, Test={counts['test']}, Valid={counts['valid']}, Total={total}")
# Out:
# Contagem total por classe com nomes numerados e nomes reais (ordem alfabética):
# Class 0 (Akarna_Dhanurasana): Train=810, Test=8, Valid=8, Total=826
# Class 1 (Bharadvaja's_Twist_pose_or_Bharadvajasana_I_): Train=810, Test=10, Valid=9, Total=829
# Class 2 (Boat_Pose_or_Paripurna_Navasana_): Train=810, Test=41, Valid=41, Total=892
# Class 3 (Bound_Angle_Pose_or_Baddha_Konasana_): Train=810, Test=32, Valid=31, Total=873
# Class 4 (Bow_Pose_or_Dhanurasana_): Train=810, Test=21, Valid=21, Total=852
# Class 5 (Bridge_Pose_or_Setu_Bandha_Sarvangasana_): Train=810, Test=25, Valid=25, Total=860
# Class 6 (Camel_Pose_or_Ustrasana_): Train=810, Test=32, Valid=32, Total=874
# Class 7 (Cat_Cow_Pose_or_Marjaryasana_): Train=810, Test=47, Valid=46, Total=903
# Class 8 (Chair_Pose_or_Utkatasana_): Train=810, Test=34, Valid=33, Total=877
# Class 9 (Child_Pose_or_Balasana_): Train=810, Test=25, Valid=24, Total=859
# Class 10 (Cobra_Pose_or_Bhujangasana_): Train=810, Test=82, Valid=81, Total=973
# Class 11 (Cockerel_Pose): Train=810, Test=14, Valid=13, Total=837
# Class 12 (Corpse_Pose_or_Savasana_): Train=810, Test=34, Valid=34, Total=878
# Class 13 (Cow_Face_Pose_or_Gomukhasana_): Train=810, Test=32, Valid=31, Total=873
# Class 14 (Crane_(Crow)_Pose_or_Bakasana_): Train=810, Test=29, Valid=28, Total=867
# Class 15 (Dolphin_Plank_Pose_or_Makara_Adho_Mukha_Svanasana_): Train=810, Test=4, Valid=4, Total=818
# Class 16 (Dolphin_Pose_or_Ardha_Pincha_Mayurasana_): Train=810, Test=6, Valid=5, Total=821
# Class 17 (Downward-Facing_Dog_pose_or_Adho_Mukha_Svanasana_): Train=810, Test=31, Valid=30, Total=871
# Class 18 (Eagle_Pose_or_Garudasana_): Train=810, Test=32, Valid=32, Total=874
# Class 19 (Eight-Angle_Pose_or_Astavakrasana_): Train=810, Test=20, Valid=19, Total=849
# Class 20 (Extended_Puppy_Pose_or_Uttana_Shishosana_): Train=810, Test=8, Valid=7, Total=825
# Class 21 (Extended_Revolved_Side_Angle_Pose_or_Utthita_Parsvakonasana_): Train=810, Test=65, Valid=65, Total=940
# Class 22 (Extended_Revolved_Triangle_Pose_or_Utthita_Trikonasana_): Train=810, Test=63, Valid=63, Total=936
# Class 23 (Feathered_Peacock_Pose_or_Pincha_Mayurasana_): Train=810, Test=26, Valid=26, Total=862
# Class 24 (Firefly_Pose_or_Tittibhasana_): Train=810, Test=19, Valid=18, Total=847
# Class 25 (Fish_Pose_or_Matsyasana_): Train=810, Test=30, Valid=29, Total=869
# Class 26 (Four-Limbed_Staff_Pose_or_Chaturanga_Dandasana_): Train=810, Test=26, Valid=25, Total=861
# Class 27 (Frog_Pose_or_Bhekasana): Train=810, Test=18, Valid=17, Total=845
# Class 28 (Garland_Pose_or_Malasana_): Train=810, Test=21, Valid=21, Total=852
# Class 29 (Gate_Pose_or_Parighasana_): Train=810, Test=17, Valid=17, Total=844
# Class 30 (Half_Lord_of_the_Fishes_Pose_or_Ardha_Matsyendrasana_): Train=810, Test=38, Valid=37, Total=885
# Class 31 (Half_Moon_Pose_or_Ardha_Chandrasana_): Train=810, Test=32, Valid=31, Total=873
# Class 32 (Handstand_pose_or_Adho_Mukha_Vrksasana_): Train=810, Test=23, Valid=23, Total=856
# Class 33 (Happy_Baby_Pose_or_Ananda_Balasana_): Train=810, Test=15, Valid=15, Total=840
# Class 34 (Head-to-Knee_Forward_Bend_pose_or_Janu_Sirsasana_): Train=810, Test=17, Valid=17, Total=844
# Class 35 (Heron_Pose_or_Krounchasana_): Train=810, Test=15, Valid=15, Total=840
# Class 36 (Intense_Side_Stretch_Pose_or_Parsvottanasana_): Train=810, Test=21, Valid=20, Total=851
# Class 37 (Legs-Up-the-Wall_Pose_or_Viparita_Karani_): Train=810, Test=24, Valid=24, Total=858
# Class 38 (Locust_Pose_or_Salabhasana_): Train=810, Test=24, Valid=24, Total=858
# Class 39 (Lord_of_the_Dance_Pose_or_Natarajasana_): Train=810, Test=47, Valid=46, Total=903
# Class 40 (Low_Lunge_pose_or_Anjaneyasana_): Train=810, Test=32, Valid=31, Total=873
# Class 41 (Noose_Pose_or_Pasasana_): Train=810, Test=4, Valid=4, Total=818
# Class 42 (Peacock_Pose_or_Mayurasana_): Train=810, Test=15, Valid=14, Total=839
# Class 43 (Pigeon_Pose_or_Kapotasana_): Train=810, Test=5, Valid=5, Total=820
# Class 44 (Plank_Pose_or_Kumbhakasana_): Train=810, Test=8, Valid=8, Total=826
# Class 45 (Plow_Pose_or_Halasana_): Train=810, Test=26, Valid=26, Total=862
# Class 46 (Pose_Dedicated_to_the_Sage_Koundinya_or_Eka_Pada_Koundinyanasana_I_and_II): Train=810, Test=16, Valid=15, Total=841
# Class 47 (Rajakapotasana): Train=810, Test=26, Valid=25, Total=861
# Class 48 (Reclining_Hand-to-Big-Toe_Pose_or_Supta_Padangusthasana_): Train=810, Test=17, Valid=16, Total=843
# Class 49 (Revolved_Head-to-Knee_Pose_or_Parivrtta_Janu_Sirsasana_): Train=810, Test=29, Valid=28, Total=867
# Class 50 (Scale_Pose_or_Tolasana_): Train=810, Test=17, Valid=16, Total=843
# Class 51 (Scorpion_pose_or_vrischikasana): Train=810, Test=24, Valid=23, Total=857
# Class 52 (Seated_Forward_Bend_pose_or_Paschimottanasana_): Train=810, Test=28, Valid=28, Total=866
# Class 53 (Shoulder-Pressing_Pose_or_Bhujapidasana_): Train=810, Test=11, Valid=10, Total=831
# Class 54 (Side-Reclining_Leg_Lift_pose_or_Anantasana_): Train=810, Test=7, Valid=7, Total=824
# Class 55 (Side_Crane_(Crow)_Pose_or_Parsva_Bakasana_): Train=810, Test=21, Valid=21, Total=852
# Class 56 (Side_Plank_Pose_or_Vasisthasana_): Train=810, Test=36, Valid=36, Total=882
# Class 57 (Sitting pose 1 (normal)): Train=810, Test=77, Valid=76, Total=963
# Class 58 (Split pose): Train=810, Test=36, Valid=36, Total=882
# Class 59 (Staff_Pose_or_Dandasana_): Train=810, Test=7, Valid=7, Total=824
# Class 60 (Standing_Forward_Bend_pose_or_Uttanasana_): Train=810, Test=41, Valid=41, Total=892
# Class 61 (Standing_Split_pose_or_Urdhva_Prasarita_Eka_Padasana_): Train=810, Test=15, Valid=14, Total=839
# Class 62 (Standing_big_toe_hold_pose_or_Utthita_Padangusthasana): Train=810, Test=22, Valid=21, Total=853
# Class 63 (Supported_Headstand_pose_or_Salamba_Sirsasana_): Train=810, Test=37, Valid=36, Total=883
# Class 64 (Supported_Shoulderstand_pose_or_Salamba_Sarvangasana_): Train=810, Test=27, Valid=26, Total=863
# Class 65 (Supta_Baddha_Konasana_): Train=810, Test=38, Valid=38, Total=886
# Class 66 (Supta_Virasana_Vajrasana): Train=810, Test=30, Valid=29, Total=869
# Class 67 (Tortoise_Pose): Train=810, Test=10, Valid=9, Total=829
# Class 68 (Tree_Pose_or_Vrksasana_): Train=810, Test=30, Valid=29, Total=869
# Class 69 (Upward_Bow_(Wheel)_Pose_or_Urdhva_Dhanurasana_): Train=810, Test=10, Valid=9, Total=829
# Class 70 (Upward_Facing_Two-Foot_Staff_Pose_or_Dwi_Pada_Viparita_Dandasana_): Train=810, Test=10, Valid=10, Total=830
# Class 71 (Upward_Plank_Pose_or_Purvottanasana_): Train=810, Test=25, Valid=24, Total=859
# Class 72 (Viparita_virabhadrasana_or_reverse_warrior_pose): Train=810, Test=15, Valid=15, Total=840
# Class 73 (Virasana_or_Vajrasana): Train=810, Test=42, Valid=41, Total=893
# Class 74 (Warrior_III_Pose_or_Virabhadrasana_III_): Train=810, Test=15, Valid=15, Total=840
# Class 75 (Warrior_II_Pose_or_Virabhadrasana_II_): Train=810, Test=35, Valid=34, Total=879
# Class 76 (Warrior_I_Pose_or_Virabhadrasana_I_): Train=810, Test=28, Valid=28, Total=866
# Class 77 (Wide-Angle_Seated_Forward_Bend_pose_or_Upavistha_Konasana_): Train=810, Test=27, Valid=26, Total=863
# Class 78 (Wide-Legged_Forward_Bend_pose_or_Prasarita_Padottanasana_): Train=810, Test=32, Valid=31, Total=873
# Class 79 (Wild_Thing_pose_or_Camatkarasana_): Train=810, Test=26, Valid=26, Total=862
# Class 80 (Wind_Relieving_pose_or_Pawanmuktasana): Train=810, Test=22, Valid=22, Total=854
# Class 81 (Yogic_sleep_pose): Train=810, Test=9, Valid=8, Total=827

# %% [markdown]
# # Dataset preprocessing

# %%
train_ds = tf.data.Dataset.list_files(str(dataset_path/'train/*/*.npy'), shuffle=True)

val_ds = tf.data.Dataset.list_files(str(dataset_path/'valid/*/*.npy'), shuffle=False)

test_ds = tf.data.Dataset.list_files(str(dataset_path/'test/*/*.npy'), shuffle=False)

# %%
def count_elements(dataset):
    count = 0
    for _ in dataset:
        count += 1
    return count

train_ds_count = count_elements(train_ds)
val_ds_count = count_elements(val_ds)
test_ds_count = count_elements(test_ds)

print(f"Tamanho do train_ds: {train_ds_count}")
print(f"Tamanho do val_ds: {val_ds_count}")
print(f"Tamanho do test_ds: {test_ds_count}")
# Out:
# Tamanho do train_ds: 66420
# Tamanho do val_ds: 2051
# Tamanho do test_ds: 2096

# %%
for f in train_ds.take(5):
    print(f.numpy())
# Out:
# b'kp_ds_aug_balan_3/train/Low_Lunge_pose_or_Anjaneyasana_/aug_Low_Lunge_pose_or_Anjaneyasana__714.npy'
# b'kp_ds_aug_balan_3/train/Four-Limbed_Staff_Pose_or_Chaturanga_Dandasana_/flipped_219.npy'
# b'kp_ds_aug_balan_3/train/Locust_Pose_or_Salabhasana_/aug_Locust_Pose_or_Salabhasana__755.npy'
# b'kp_ds_aug_balan_3/train/Downward-Facing_Dog_pose_or_Adho_Mukha_Svanasana_/flipped_320.npy'
# b'kp_ds_aug_balan_3/train/Feathered_Peacock_Pose_or_Pincha_Mayurasana_/aug_Feathered_Peacock_Pose_or_Pincha_Mayurasana__312.npy'

# %%
class_names = np.array(sorted([item.name for item in dataset_path.glob('train/*')]))
class_names
# Out:
# array(['Akarna_Dhanurasana',
#        "Bharadvaja's_Twist_pose_or_Bharadvajasana_I_",
#        'Boat_Pose_or_Paripurna_Navasana_',
#        'Bound_Angle_Pose_or_Baddha_Konasana_', 'Bow_Pose_or_Dhanurasana_',
#        'Bridge_Pose_or_Setu_Bandha_Sarvangasana_',
#        'Camel_Pose_or_Ustrasana_', 'Cat_Cow_Pose_or_Marjaryasana_',
#        'Chair_Pose_or_Utkatasana_', 'Child_Pose_or_Balasana_',
#        'Cobra_Pose_or_Bhujangasana_', 'Cockerel_Pose',
#        'Corpse_Pose_or_Savasana_', 'Cow_Face_Pose_or_Gomukhasana_',
#        'Crane_(Crow)_Pose_or_Bakasana_',
#        'Dolphin_Plank_Pose_or_Makara_Adho_Mukha_Svanasana_',
#        'Dolphin_Pose_or_Ardha_Pincha_Mayurasana_',
#        'Downward-Facing_Dog_pose_or_Adho_Mukha_Svanasana_',
#        'Eagle_Pose_or_Garudasana_', 'Eight-Angle_Pose_or_Astavakrasana_',
#        'Extended_Puppy_Pose_or_Uttana_Shishosana_',
#        'Extended_Revolved_Side_Angle_Pose_or_Utthita_Parsvakonasana_',
#        'Extended_Revolved_Triangle_Pose_or_Utthita_Trikonasana_',
#        'Feathered_Peacock_Pose_or_Pincha_Mayurasana_',
#        'Firefly_Pose_or_Tittibhasana_', 'Fish_Pose_or_Matsyasana_',
#        'Four-Limbed_Staff_Pose_or_Chaturanga_Dandasana_',
#        'Frog_Pose_or_Bhekasana', 'Garland_Pose_or_Malasana_',
#        'Gate_Pose_or_Parighasana_',
#        'Half_Lord_of_the_Fishes_Pose_or_Ardha_Matsyendrasana_',
#        'Half_Moon_Pose_or_Ardha_Chandrasana_',
#        'Handstand_pose_or_Adho_Mukha_Vrksasana_',
#        'Happy_Baby_Pose_or_Ananda_Balasana_',
#        'Head-to-Knee_Forward_Bend_pose_or_Janu_Sirsasana_',
#        'Heron_Pose_or_Krounchasana_',
#        'Intense_Side_Stretch_Pose_or_Parsvottanasana_',
#        'Legs-Up-the-Wall_Pose_or_Viparita_Karani_',
#        'Locust_Pose_or_Salabhasana_',
#        'Lord_of_the_Dance_Pose_or_Natarajasana_',
#        'Low_Lunge_pose_or_Anjaneyasana_', 'Noose_Pose_or_Pasasana_',
#        'Peacock_Pose_or_Mayurasana_', 'Pigeon_Pose_or_Kapotasana_',
#        'Plank_Pose_or_Kumbhakasana_', 'Plow_Pose_or_Halasana_',
#        'Pose_Dedicated_to_the_Sage_Koundinya_or_Eka_Pada_Koundinyanasana_I_and_II',
#        'Rajakapotasana',
#        'Reclining_Hand-to-Big-Toe_Pose_or_Supta_Padangusthasana_',
#        'Revolved_Head-to-Knee_Pose_or_Parivrtta_Janu_Sirsasana_',
#        'Scale_Pose_or_Tolasana_', 'Scorpion_pose_or_vrischikasana',
#        'Seated_Forward_Bend_pose_or_Paschimottanasana_',
#        'Shoulder-Pressing_Pose_or_Bhujapidasana_',
#        'Side-Reclining_Leg_Lift_pose_or_Anantasana_',
#        'Side_Crane_(Crow)_Pose_or_Parsva_Bakasana_',
#        'Side_Plank_Pose_or_Vasisthasana_', 'Sitting pose 1 (normal)',
#        'Split pose', 'Staff_Pose_or_Dandasana_',
#        'Standing_Forward_Bend_pose_or_Uttanasana_',
#        'Standing_Split_pose_or_Urdhva_Prasarita_Eka_Padasana_',
#        'Standing_big_toe_hold_pose_or_Utthita_Padangusthasana',
#        'Supported_Headstand_pose_or_Salamba_Sirsasana_',
#        'Supported_Shoulderstand_pose_or_Salamba_Sarvangasana_',
#        'Supta_Baddha_Konasana_', 'Supta_Virasana_Vajrasana',
#        'Tortoise_Pose', 'Tree_Pose_or_Vrksasana_',
#        'Upward_Bow_(Wheel)_Pose_or_Urdhva_Dhanurasana_',
#        'Upward_Facing_Two-Foot_Staff_Pose_or_Dwi_Pada_Viparita_Dandasana_',
#        'Upward_Plank_Pose_or_Purvottanasana_',
#        'Viparita_virabhadrasana_or_reverse_warrior_pose',
#        'Virasana_or_Vajrasana', 'Warrior_III_Pose_or_Virabhadrasana_III_',
#        'Warrior_II_Pose_or_Virabhadrasana_II_',
#        'Warrior_I_Pose_or_Virabhadrasana_I_',
#        'Wide-Angle_Seated_Forward_Bend_pose_or_Upavistha_Konasana_',
#        'Wide-Legged_Forward_Bend_pose_or_Prasarita_Padottanasana_',
#        'Wild_Thing_pose_or_Camatkarasana_',
#        'Wind_Relieving_pose_or_Pawanmuktasana', 'Yogic_sleep_pose'],
#       dtype='<U73')

# %%
num_classes = len(class_names)
num_classes
# Out:
# 82

# %% [markdown]
# ## `tf.data` preprocessing

# %%
def get_label(file_path):
    """
    Retrieves the label (class) from the file path.
    """
    parts = tf.strings.split(file_path, os.path.sep)
    one_hot = parts[-2] == class_names
    return tf.argmax(one_hot)

def decode_npy(file_path):
    """
    Loads data from a .npy file.
    """
    # Using tf.numpy_function to load the .npy file with numpy
    def load_npy(path):
        return np.load(path.decode('utf-8')).astype(np.float32)

    # Convert the path to a tensor using numpy_function
    npy_data = tf.numpy_function(load_npy, [file_path], tf.float32)
    npy_data.set_shape([33, 4])
    return npy_data

def process_path(file_path, label=None):
    """
    Processes the file path to obtain data and labels.
    """
    label = get_label(file_path)  # Retrieve label
    data = decode_npy(file_path)  # Load data from the .npy file
    return data, label

# %%
# Dataset mapping
train_ds = train_ds.map(process_path, num_parallel_calls=tf.data.AUTOTUNE)
val_ds = val_ds.map(process_path, num_parallel_calls=tf.data.AUTOTUNE)
test_ds = test_ds.map(process_path, num_parallel_calls=tf.data.AUTOTUNE)

# %%
for input_batch, label_batch in train_ds.take(1):
    print(input_batch.shape)
    print(label_batch.numpy())
# Out:
# (33, 4)
# 40

# %%
def configure_for_performance(ds, shuffle=False):
    """
    Configures the dataset for better performance during training.
    """
    ds = ds.cache()
    if shuffle:
        ds = ds.shuffle(buffer_size=1000)
    ds = ds.batch(32)
    ds = ds.prefetch(buffer_size=tf.data.AUTOTUNE)
    return ds

# %%
train_ds = configure_for_performance(train_ds, shuffle=True)
val_ds = configure_for_performance(val_ds, shuffle=False)
test_ds = configure_for_performance(test_ds, shuffle=False)

# %% [markdown]
# # Transformer with CNN extraction

# %% [markdown]
# ## Transformer Encoder

# %%
init = HeUniform(seed=42)
reg1 = l2(1e-4)
reg2 = l2(1e-5)

# %%
@tf.keras.utils.register_keras_serializable()
class TransformerEncoder(layers.Layer):
  def __init__(self, num_heads, conv_dim, name, **kwargs):
    super(TransformerEncoder, self).__init__(name=name, **kwargs)

    self.num_heads = num_heads
    self.conv_dim = conv_dim

    self.layer_norm = layers.LayerNormalization()
    self.mha = layers.MultiHeadAttention(self.num_heads, self.conv_dim,
                                         kernel_initializer=init)
    self.conv_proj = tf.keras.Sequential([
        layers.Dense(self.conv_dim, activation='relu', kernel_regularizer=reg1, bias_regularizer=reg1, activity_regularizer=reg2),
        layers.Dense(self.conv_dim, activation='relu', kernel_regularizer=reg1, bias_regularizer=reg1, activity_regularizer=reg2),
        layers.Dense(self.conv_dim, kernel_regularizer=reg1, bias_regularizer=reg1, activity_regularizer=reg2)
    ])

  def build(self, input_shape):
    super(TransformerEncoder, self).build(input_shape)

  def call(self, inputs):
    attention_output = self.mha(query=inputs, value=inputs, key=inputs)
    proj_input = self.layer_norm(inputs + attention_output)
    proj_output = self.conv_proj(proj_input)
    return self.layer_norm(proj_input + proj_output)

  def get_config(self):
    config = super().get_config()
    config.update({
        "num_heads": self.mha.num_heads,
        "conv_dim": self.mha.key_dim,
    })
    return config

# %% [markdown]
# ## Model architecture

# %%
input_shape = (33, 4)

inputs = tf.keras.Input(shape=input_shape)
x = layers.MultiHeadAttention(num_heads=4, key_dim=16)(inputs, inputs)
x = inputs + x
x = layers.Conv1D(filters=80, kernel_size=5, padding="same")(x)
x = layers.BatchNormalization()(x)
x = layers.Activation('relu')(x)
x = layers.Conv1D(filters=48, kernel_size=5, padding="same", kernel_regularizer=reg1)(x)
x = layers.BatchNormalization()(x)
x = layers.Activation('relu')(x)
x = layers.Dropout(0.25)(x)
x = layers.Conv1D(filters=16, kernel_size=5, padding="same", kernel_regularizer=reg1, bias_regularizer=reg1, activity_regularizer=reg2)(x)
x = layers.BatchNormalization()(x)
x = layers.Activation('relu')(x)
x = TransformerEncoder(num_heads=4, conv_dim=16, name='transformer_encoder')(x)
x = layers.Flatten()(x)
x = layers.Dense(88, activation='relu', kernel_regularizer=reg1, bias_regularizer=reg1, activity_regularizer=reg2)(x)
x = layers.Dropout(0.5)(x)
outputs = layers.Dense(num_classes, activation='softmax')(x)

transformer = keras.Model(inputs=inputs, outputs=outputs)

# %%
transformer.summary()
# Out:
# Model: "functional_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)              ┃ Output Shape           ┃        Param # ┃ Connected to           ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)  │ (None, 33, 4)          │              0 │ -                      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ multi_head_attention      │ (None, 33, 4)          │          1,220 │ input_layer[0][0],     │
# │ (MultiHeadAttention)      │                        │                │ input_layer[0][0]      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ add (Add)                 │ (None, 33, 4)          │              0 │ input_layer[0][0],     │
# │                           │                        │                │ multi_head_attention[… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv1d (Conv1D)           │ (None, 33, 80)         │          1,680 │ add[0][0]              │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization       │ (None, 33, 80)         │            320 │ conv1d[0][0]           │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ activation (Activation)   │ (None, 33, 80)         │              0 │ batch_normalization[0… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv1d_1 (Conv1D)         │ (None, 33, 48)         │         19,248 │ activation[0][0]       │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_1     │ (None, 33, 48)         │            192 │ conv1d_1[0][0]         │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ activation_1 (Activation) │ (None, 33, 48)         │              0 │ batch_normalization_1… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dropout_1 (Dropout)       │ (None, 33, 48)         │              0 │ activation_1[0][0]     │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv1d_2 (Conv1D)         │ (None, 33, 16)         │          3,856 │ dropout_1[0][0]        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_2     │ (None, 33, 16)         │             64 │ conv1d_2[0][0]         │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ activation_2 (Activation) │ (None, 33, 16)         │              0 │ batch_normalization_2… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ transformer_encoder       │ (None, 33, 16)         │          5,152 │ activation_2[0][0]     │
# │ (TransformerEncoder)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ flatten (Flatten)         │ (None, 528)            │              0 │ transformer_encoder[0… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_3 (Dense)           │ (None, 88)             │         46,552 │ flatten[0][0]          │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dropout_3 (Dropout)       │ (None, 88)             │              0 │ dense_3[0][0]          │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_4 (Dense)           │ (None, 82)             │          7,298 │ dropout_3[0][0]        │
# └───────────────────────────┴────────────────────────┴────────────────┴────────────────────────┘
#  Total params: 85,582 (334.30 KB)
#  Trainable params: 85,294 (333.18 KB)
#  Non-trainable params: 288 (1.12 KB)

# %% [markdown]
# ## Model training

# %%
def scheduler(epoch, lr):
  if epoch < 20:
    return lr
  else:
    return lr * float(tf.math.exp(-0.1))

callbacks = [
    ModelCheckpoint(filepath='kp_ds_aug_balan_3_model_1_tranformer_cnn.keras',
                    save_best_only=True,
                    monitor='val_accuracy',
                    verbose=1),
    LearningRateScheduler(scheduler),
    EarlyStopping(monitor='val_accuracy', patience=15, restore_best_weights=True)
]

# %%
transformer.compile(optimizer=tf.keras.optimizers.AdamW(learning_rate=1e-3),
            loss=tf.keras.losses.SparseCategoricalCrossentropy(),
            metrics=['accuracy'])

# %%
history = transformer.fit(
    train_ds,
    epochs=150,
    validation_data=val_ds,
    callbacks=callbacks)
# Out:
# Epoch 1/150
# 2076/2076 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.3494 - loss: 2.7697
# Epoch 1: val_accuracy improved from -inf to 0.78840, saving model to kp_ds_aug_balan_3_model_1_tranformer_cnn.keras
# 2076/2076 ━━━━━━━━━━━━━━━━━━━━ 62s 23ms/step - accuracy: 0.3495 - loss: 2.7693 - val_accuracy: 0.7884 - val_loss: 0.9298 - learning_rate: 0.0010
# Epoch 2/150
# 2062/2076 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7426 - loss: 1.0561
# Epoch 2: val_accuracy improved from 0.78840 to 0.83813, saving model to kp_ds_aug_balan_3_model_1_tranformer_cnn.keras
# 2076/2076 ━━━━━━━━━━━━━━━━━━━━ 7s 3ms/step - accuracy: 0.7427 - loss: 1.0556 - val_accuracy: 0.8381 - val_loss: 0.7520 - learning_rate: 0.0010
# Epoch 3/150
# 2065/2076 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7939 - loss: 0.8674
# Epoch 3: val_accuracy did not improve from 0.83813
# 2076/2076 ━━━━━━━━━━━━━━━━━━━━ 7s 3ms/step - accuracy: 0.7939 - loss: 0.8672 - val_accuracy: 0.8128 - val_loss: 0.8162 - learning_rate: 0.0010
# Epoch 4/150
# 2061/2076 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8152 - loss: 0.7769
# Epoch 4: val_accuracy improved from 0.83813 to 0.85909, saving model to kp_ds_aug_balan_3_model_1_tranformer_cnn.keras
# 2076/2076 ━━━━━━━━━━━━━━━━━━━━ 7s 3ms/step - accuracy: 0.8152 - loss: 0.7768 - val_accuracy: 0.8591 - val_loss: 0.6717 - learning_rate: 0.0010
# Epoch 5/150
# 2068/2076 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8311 - loss: 0.7166
# Epoch 5: val_accuracy did not improve from 0.85909
# 2076/2076 ━━━━━━━━━━━━━━━━━━━━ 7s 3ms/step - accuracy: 0.8311 - loss: 0.7165 - val_accuracy: 0.8503 - val_loss: 0.6569 - learning_rate: 0.0010
# Epoch 6/150
# 2068/2076 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8387 - loss: 0.6786
# Epoch 6: val_accuracy improved from 0.85909 to 0.86836, saving model to kp_ds_aug_balan_3_model_1_tranformer_cnn.keras
# 2076/2076 ━━━━━━━━━━━━━━━━━━━━ 7s 3ms/step - accuracy: 0.8387 - loss: 0.6786 - val_accuracy: 0.8684 - val_loss: 0.6321 - learning_rate: 0.0010
# Epoch 7/150
# 2070/2076 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8482 - loss: 0.6481
# Epoch 7: val_accuracy did not improve from 0.86836
# 2076/2076 ━━━━━━━━━━━━━━━━━━━━ 7s 3ms/step - accuracy: 0.8482 - loss: 0.6481 - val_accuracy: 0.8606 - val_loss: 0.6793 - learning_rate: 0.0010
# Epoch 8/150
# 2067/2076 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8548 - loss: 0.6244
# Epoch 8: val_accuracy improved from 0.86836 to 0.86982, saving model to kp_ds_aug_balan_3_model_1_tranformer_cnn.keras
# 2076/2076 ━━━━━━━━━━━━━━━━━━━━ 7s 3ms/step - accuracy: 0.8549 - loss: 0.6244 - val_accuracy: 0.8698 - val_loss: 0.6218 - learning_rate: 0.0010
# Epoch 9/150
# 2073/2076 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8595 - loss: 0.6077
# Epoch 9: val_accuracy did not improve from 0.86982
# 2076/2076 ━━━━━━━━━━━━━━━━━━━━ 7s 3ms/step - accuracy: 0.8595 - loss: 0.6077 - val_accuracy: 0.8679 - val_loss: 0.6393 - learning_rate: 0.0010
# Epoch 10/150
# 2065/2076 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8634 - loss: 0.5872
# Epoch 10: val_accuracy improved from 0.86982 to 0.87470, saving model to kp_ds_aug_balan_3_model_1_tranformer_cnn.keras
# 2076/2076 ━━━━━━━━━━━━━━━━━━━━ 7s 3ms/step - accuracy: 0.8634 - loss: 0.5872 - val_accuracy: 0.8747 - val_loss: 0.6333 - learning_rate: 0.0010
# Epoch 11/150
# 2075/2076 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8675 - loss: 0.5762
# Epoch 11: val_accuracy improved from 0.87470 to 0.87567, saving model to kp_ds_aug_balan_3_model_1_tranformer_cnn.keras
# 2076/2076 ━━━━━━━━━━━━━━━━━━━━ 7s 3ms/step - accuracy: 0.8675 - loss: 0.5762 - val_accuracy: 0.8757 - val_loss: 0.6296 - learning_rate: 0.0010
# Epoch 12/150
# 2062/2076 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8723 - loss: 0.5629
# Epoch 12: val_accuracy improved from 0.87567 to 0.87908, saving model to kp_ds_aug_balan_3_model_1_tranformer_cnn.keras
# 2076/2076 ━━━━━━━━━━━━━━━━━━━━ 7s 3ms/step - accuracy: 0.8723 - loss: 0.5628 - val_accuracy: 0.8791 - val_loss: 0.6176 - learning_rate: 0.0010
# Epoch 13/150
# 2067/2076 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8751 - loss: 0.5508
# Epoch 13: val_accuracy did not improve from 0.87908
# 2076/2076 ━━━━━━━━━━━━━━━━━━━━ 7s 3ms/step - accuracy: 0.8751 - loss: 0.5508 - val_accuracy: 0.8747 - val_loss: 0.6174 - learning_rate: 0.0010
# Epoch 14/150
# 2067/2076 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8770 - loss: 0.5427
# Epoch 14: val_accuracy did not improve from 0.87908
# 2076/2076 ━━━━━━━━━━━━━━━━━━━━ 7s 3ms/step - accuracy: 0.8770 - loss: 0.5426 - val_accuracy: 0.8766 - val_loss: 0.6116 - learning_rate: 0.0010
# Epoch 15/150
# 2062/2076 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8792 - loss: 0.5317
# Epoch 15: val_accuracy did not improve from 0.87908
# 2076/2076 ━━━━━━━━━━━━━━━━━━━━ 7s 3ms/step - accuracy: 0.8792 - loss: 0.5317 - val_accuracy: 0.8708 - val_loss: 0.6492 - learning_rate: 0.0010
# Epoch 16/150
# 2066/2076 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8826 - loss: 0.5254
# Epoch 16: val_accuracy did not improve from 0.87908
# 2076/2076 ━━━━━━━━━━━━━━━━━━━━ 7s 3ms/step - accuracy: 0.8826 - loss: 0.5254 - val_accuracy: 0.8781 - val_loss: 0.6151 - learning_rate: 0.0010
# Epoch 17/150
# 2072/2076 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8814 - loss: 0.5273
# Epoch 17: val_accuracy did not improve from 0.87908
# 2076/2076 ━━━━━━━━━━━━━━━━━━━━ 7s 3ms/step - accuracy: 0.8814 - loss: 0.5273 - val_accuracy: 0.8786 - val_loss: 0.6274 - learning_rate: 0.0010
# Epoch 18/150
# 2063/2076 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8842 - loss: 0.5155
# Epoch 18: val_accuracy improved from 0.87908 to 0.88103, saving model to kp_ds_aug_balan_3_model_1_tranformer_cnn.keras
# 2076/2076 ━━━━━━━━━━━━━━━━━━━━ 7s 3ms/step - accuracy: 0.8842 - loss: 0.5155 - val_accuracy: 0.8810 - val_loss: 0.6223 - learning_rate: 0.0010
# Epoch 19/150
# 2074/2076 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8856 - loss: 0.5114
# Epoch 19: val_accuracy did not improve from 0.88103
# 2076/2076 ━━━━━━━━━━━━━━━━━━━━ 7s 3ms/step - accuracy: 0.8856 - loss: 0.5113 - val_accuracy: 0.8781 - val_loss: 0.6052 - learning_rate: 0.0010
# Epoch 20/150
# 2065/2076 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8879 - loss: 0.4981
# Epoch 20: val_accuracy did not improve from 0.88103
# 2076/2076 ━━━━━━━━━━━━━━━━━━━━ 7s 3ms/step - accuracy: 0.8879 - loss: 0.4981 - val_accuracy: 0.8688 - val_loss: 0.6271 - learning_rate: 0.0010
# Epoch 21/150
# 2075/2076 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8921 - loss: 0.4890
# Epoch 21: val_accuracy did not improve from 0.88103
# 2076/2076 ━━━━━━━━━━━━━━━━━━━━ 7s 3ms/step - accuracy: 0.8921 - loss: 0.4890 - val_accuracy: 0.8766 - val_loss: 0.6268 - learning_rate: 9.0484e-04
# Epoch 22/150
# 2071/2076 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8923 - loss: 0.4757
# Epoch 22: val_accuracy did not improve from 0.88103
# 2076/2076 ━━━━━━━━━━━━━━━━━━━━ 7s 3ms/step - accuracy: 0.8923 - loss: 0.4757 - val_accuracy: 0.8776 - val_loss: 0.6286 - learning_rate: 8.1873e-04
# Epoch 23/150
# 2063/2076 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8994 - loss: 0.4566
# Epoch 23: val_accuracy did not improve from 0.88103
# 2076/2076 ━━━━━━━━━━━━━━━━━━━━ 7s 3ms/step - accuracy: 0.8994 - loss: 0.4565 - val_accuracy: 0.8786 - val_loss: 0.6146 - learning_rate: 7.4082e-04
# Epoch 24/150
# 2076/2076 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9032 - loss: 0.4429
# Epoch 24: val_accuracy improved from 0.88103 to 0.88493, saving model to kp_ds_aug_balan_3_model_1_tranformer_cnn.keras
# 2076/2076 ━━━━━━━━━━━━━━━━━━━━ 7s 3ms/step - accuracy: 0.9032 - loss: 0.4429 - val_accuracy: 0.8849 - val_loss: 0.6237 - learning_rate: 6.7032e-04
# Epoch 25/150
# 2072/2076 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9035 - loss: 0.4302
# Epoch 25: val_accuracy did not improve from 0.88493
# 2076/2076 ━━━━━━━━━━━━━━━━━━━━ 7s 3ms/step - accuracy: 0.9035 - loss: 0.4302 - val_accuracy: 0.8830 - val_loss: 0.6248 - learning_rate: 6.0653e-04
# Epoch 26/150
# 2072/2076 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9084 - loss: 0.4126
# Epoch 26: val_accuracy did not improve from 0.88493
# 2076/2076 ━━━━━━━━━━━━━━━━━━━━ 7s 3ms/step - accuracy: 0.9084 - loss: 0.4125 - val_accuracy: 0.8810 - val_loss: 0.6000 - learning_rate: 5.4881e-04
# Epoch 27/150
# 2066/2076 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9132 - loss: 0.3972
# Epoch 27: val_accuracy improved from 0.88493 to 0.88640, saving model to kp_ds_aug_balan_3_model_1_tranformer_cnn.keras
# 2076/2076 ━━━━━━━━━━━━━━━━━━━━ 7s 3ms/step - accuracy: 0.9132 - loss: 0.3972 - val_accuracy: 0.8864 - val_loss: 0.5945 - learning_rate: 4.9659e-04
# Epoch 28/150
# 2062/2076 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9156 - loss: 0.3870
# Epoch 28: val_accuracy improved from 0.88640 to 0.88688, saving model to kp_ds_aug_balan_3_model_1_tranformer_cnn.keras
# 2076/2076 ━━━━━━━━━━━━━━━━━━━━ 7s 3ms/step - accuracy: 0.9156 - loss: 0.3870 - val_accuracy: 0.8869 - val_loss: 0.5952 - learning_rate: 4.4933e-04
# Epoch 29/150
# 2068/2076 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9174 - loss: 0.3804
# Epoch 29: val_accuracy improved from 0.88688 to 0.89274, saving model to kp_ds_aug_balan_3_model_1_tranformer_cnn.keras
# 2076/2076 ━━━━━━━━━━━━━━━━━━━━ 7s 3ms/step - accuracy: 0.9174 - loss: 0.3803 - val_accuracy: 0.8927 - val_loss: 0.5903 - learning_rate: 4.0657e-04
# Epoch 30/150
# 2068/2076 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9196 - loss: 0.3728
# Epoch 30: val_accuracy improved from 0.89274 to 0.89371, saving model to kp_ds_aug_balan_3_model_1_tranformer_cnn.keras
# 2076/2076 ━━━━━━━━━━━━━━━━━━━━ 7s 3ms/step - accuracy: 0.9196 - loss: 0.3728 - val_accuracy: 0.8937 - val_loss: 0.5885 - learning_rate: 3.6788e-04
# Epoch 31/150
# 2069/2076 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9234 - loss: 0.3568
# Epoch 31: val_accuracy did not improve from 0.89371
# 2076/2076 ━━━━━━━━━━━━━━━━━━━━ 7s 3ms/step - accuracy: 0.9234 - loss: 0.3568 - val_accuracy: 0.8888 - val_loss: 0.5916 - learning_rate: 3.3287e-04
# Epoch 32/150
# 2065/2076 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9214 - loss: 0.3547
# Epoch 32: val_accuracy did not improve from 0.89371
# 2076/2076 ━━━━━━━━━━━━━━━━━━━━ 7s 3ms/step - accuracy: 0.9214 - loss: 0.3547 - val_accuracy: 0.8898 - val_loss: 0.5887 - learning_rate: 3.0119e-04
# Epoch 33/150
# 2064/2076 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9252 - loss: 0.3395
# Epoch 33: val_accuracy did not improve from 0.89371
# 2076/2076 ━━━━━━━━━━━━━━━━━━━━ 7s 3ms/step - accuracy: 0.9252 - loss: 0.3395 - val_accuracy: 0.8937 - val_loss: 0.5910 - learning_rate: 2.7253e-04
# Epoch 34/150
# 2069/2076 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9288 - loss: 0.3320
# Epoch 34: val_accuracy did not improve from 0.89371
# 2076/2076 ━━━━━━━━━━━━━━━━━━━━ 7s 3ms/step - accuracy: 0.9288 - loss: 0.3320 - val_accuracy: 0.8932 - val_loss: 0.5844 - learning_rate: 2.4660e-04
# Epoch 35/150
# 2070/2076 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9287 - loss: 0.3297
# Epoch 35: val_accuracy did not improve from 0.89371
# 2076/2076 ━━━━━━━━━━━━━━━━━━━━ 7s 3ms/step - accuracy: 0.9287 - loss: 0.3296 - val_accuracy: 0.8918 - val_loss: 0.5800 - learning_rate: 2.2313e-04
# Epoch 36/150
# 2069/2076 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9316 - loss: 0.3207
# Epoch 36: val_accuracy did not improve from 0.89371
# 2076/2076 ━━━━━━━━━━━━━━━━━━━━ 7s 3ms/step - accuracy: 0.9316 - loss: 0.3207 - val_accuracy: 0.8898 - val_loss: 0.5880 - learning_rate: 2.0190e-04
# Epoch 37/150
# 2069/2076 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9310 - loss: 0.3197
# Epoch 37: val_accuracy improved from 0.89371 to 0.89761, saving model to kp_ds_aug_balan_3_model_1_tranformer_cnn.keras
# 2076/2076 ━━━━━━━━━━━━━━━━━━━━ 7s 3ms/step - accuracy: 0.9310 - loss: 0.3197 - val_accuracy: 0.8976 - val_loss: 0.5915 - learning_rate: 1.8268e-04
# Epoch 38/150
# 2070/2076 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9316 - loss: 0.3116
# Epoch 38: val_accuracy did not improve from 0.89761
# 2076/2076 ━━━━━━━━━━━━━━━━━━━━ 7s 3ms/step - accuracy: 0.9316 - loss: 0.3116 - val_accuracy: 0.8913 - val_loss: 0.5918 - learning_rate: 1.6530e-04
# Epoch 39/150
# 2064/2076 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9338 - loss: 0.3106
# Epoch 39: val_accuracy did not improve from 0.89761
# 2076/2076 ━━━━━━━━━━━━━━━━━━━━ 7s 3ms/step - accuracy: 0.9338 - loss: 0.3106 - val_accuracy: 0.8947 - val_loss: 0.5939 - learning_rate: 1.4957e-04
# Epoch 40/150
# 2062/2076 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9353 - loss: 0.2960
# Epoch 40: val_accuracy did not improve from 0.89761
# 2076/2076 ━━━━━━━━━━━━━━━━━━━━ 7s 3ms/step - accuracy: 0.9353 - loss: 0.2960 - val_accuracy: 0.8918 - val_loss: 0.5781 - learning_rate: 1.3534e-04
# Epoch 41/150
# 2069/2076 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9352 - loss: 0.3011
# Epoch 41: val_accuracy did not improve from 0.89761
# 2076/2076 ━━━━━━━━━━━━━━━━━━━━ 7s 3ms/step - accuracy: 0.9352 - loss: 0.3011 - val_accuracy: 0.8966 - val_loss: 0.5837 - learning_rate: 1.2246e-04
# Epoch 42/150
# 2067/2076 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9353 - loss: 0.2967
# Epoch 42: val_accuracy did not improve from 0.89761
# 2076/2076 ━━━━━━━━━━━━━━━━━━━━ 7s 3ms/step - accuracy: 0.9353 - loss: 0.2967 - val_accuracy: 0.8903 - val_loss: 0.5881 - learning_rate: 1.1080e-04
# Epoch 43/150
# 2071/2076 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9359 - loss: 0.2953
# Epoch 43: val_accuracy did not improve from 0.89761
# 2076/2076 ━━━━━━━━━━━━━━━━━━━━ 7s 3ms/step - accuracy: 0.9359 - loss: 0.2953 - val_accuracy: 0.8927 - val_loss: 0.5830 - learning_rate: 1.0026e-04
# Epoch 44/150
# 2061/2076 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9371 - loss: 0.2864
# Epoch 44: val_accuracy did not improve from 0.89761
# 2076/2076 ━━━━━━━━━━━━━━━━━━━━ 7s 3ms/step - accuracy: 0.9371 - loss: 0.2864 - val_accuracy: 0.8932 - val_loss: 0.5851 - learning_rate: 9.0718e-05
# Epoch 45/150
# 2073/2076 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9379 - loss: 0.2868
# Epoch 45: val_accuracy did not improve from 0.89761
# 2076/2076 ━━━━━━━━━━━━━━━━━━━━ 7s 3ms/step - accuracy: 0.9379 - loss: 0.2868 - val_accuracy: 0.8947 - val_loss: 0.5831 - learning_rate: 8.2085e-05
# Epoch 46/150
# 2072/2076 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9410 - loss: 0.2775
# Epoch 46: val_accuracy did not improve from 0.89761
# 2076/2076 ━━━━━━━━━━━━━━━━━━━━ 7s 3ms/step - accuracy: 0.9410 - loss: 0.2775 - val_accuracy: 0.8937 - val_loss: 0.5940 - learning_rate: 7.4273e-05
# Epoch 47/150
# 2073/2076 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9380 - loss: 0.2824
# Epoch 47: val_accuracy did not improve from 0.89761
# 2076/2076 ━━━━━━━━━━━━━━━━━━━━ 7s 3ms/step - accuracy: 0.9380 - loss: 0.2824 - val_accuracy: 0.8952 - val_loss: 0.5935 - learning_rate: 6.7205e-05
# Epoch 48/150
# 2060/2076 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9405 - loss: 0.2773
# Epoch 48: val_accuracy did not improve from 0.89761
# 2076/2076 ━━━━━━━━━━━━━━━━━━━━ 7s 3ms/step - accuracy: 0.9405 - loss: 0.2773 - val_accuracy: 0.8961 - val_loss: 0.5949 - learning_rate: 6.0810e-05
# Epoch 49/150
# 2070/2076 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9389 - loss: 0.2760
# Epoch 49: val_accuracy did not improve from 0.89761
# 2076/2076 ━━━━━━━━━━━━━━━━━━━━ 7s 3ms/step - accuracy: 0.9389 - loss: 0.2760 - val_accuracy: 0.8932 - val_loss: 0.5966 - learning_rate: 5.5023e-05
# Epoch 50/150
# 2069/2076 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9423 - loss: 0.2747
# Epoch 50: val_accuracy did not improve from 0.89761
# 2076/2076 ━━━━━━━━━━━━━━━━━━━━ 7s 3ms/step - accuracy: 0.9423 - loss: 0.2747 - val_accuracy: 0.8937 - val_loss: 0.5850 - learning_rate: 4.9787e-05
# Epoch 51/150
# 2061/2076 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9417 - loss: 0.2734
# Epoch 51: val_accuracy did not improve from 0.89761
# 2076/2076 ━━━━━━━━━━━━━━━━━━━━ 7s 3ms/step - accuracy: 0.9417 - loss: 0.2734 - val_accuracy: 0.8971 - val_loss: 0.5886 - learning_rate: 4.5049e-05
# Epoch 52/150
# 2068/2076 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9423 - loss: 0.2699
# Epoch 52: val_accuracy did not improve from 0.89761
# 2076/2076 ━━━━━━━━━━━━━━━━━━━━ 7s 3ms/step - accuracy: 0.9423 - loss: 0.2699 - val_accuracy: 0.8976 - val_loss: 0.5865 - learning_rate: 4.0762e-05

# %% [markdown]
# ## Model metrics

# %%
model = load_model("kp_ds_aug_balan_3_model_1_tranformer_cnn.keras",
                   custom_objects={"TransformerEnconder": TransformerEncoder})

print("Average loss and accuracy during training:")
print(f"loss: {np.average(history.history['loss']):.4f} - accuracy: {np.average(history.history['accuracy']) * 100:.2f}%")

print("Model validation:")
scores = model.evaluate(val_ds, verbose=0)
print(f'loss: {scores[0]:.4f} - accuracy: {scores[1]* 100:.2f}%')

plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model accuracy during training')
plt.ylabel('Accuracy')
plt.xlabel('Epochs')
plt.legend(['Train.', 'Valid.'], loc='lower right')
plt.ylim(0.5, 1.0)
plt.show()

print("\n")

plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss during training')
plt.ylabel('Loss')
plt.xlabel('Epochs')
plt.legend(['Train.', 'Valid.'], loc='upper right')
plt.show()
# Out:
# Average loss and accuracy during training:
# loss: 0.4701 - accuracy: 89.35%
# Model validation:
# loss: 0.5915 - accuracy: 89.76%

# %%
scores = model.evaluate(test_ds, verbose=0)
print("Model testing:")
print(f'loss: {scores[0]:.4f} - accuracy: {scores[1]* 100:.2f}%')
# Out:
# Model testing:
# loss: 0.5685 - accuracy: 89.74%

# %%
mapped_class_names = [class_name_map[cls] for cls in sorted_class_names]  # List of mapped class names

y_pred = np.argmax(model.predict(test_ds), axis=1)  # Get predictions based on probabilities
y_true = np.concatenate([label.numpy() for kp, label in test_ds], axis=0)  # Get true labels
# Out:
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step

# %%
# Gerar a matriz de confusão
cm = confusion_matrix(y_true, y_pred)
plt.figure(figsize=(40, 40))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues',
            xticklabels=mapped_class_names,
            yticklabels=mapped_class_names)
plt.xlabel('Predicted')
plt.ylabel('True')
plt.title('Confusion Matrix')
plt.show()

# %%
# Classification report
report = classification_report(y_true, y_pred, target_names=mapped_class_names, output_dict=True)
report_df = pd.DataFrame(report)
report_df.to_csv("kp_ds_aug_balan_3_report_transformer.csv", index=True)
report_df
# Out:
#             Class 0    Class 1   Class 2    Class 3    Class 4    Class 5  \
# precision  0.800000   0.466667   0.97561   0.878788   0.952381   0.857143
# recall     1.000000   0.700000   0.97561   0.906250   0.952381   0.960000
# f1-score   0.888889   0.560000   0.97561   0.892308   0.952381   0.905660
# support    8.000000  10.000000  41.00000  32.000000  21.000000  25.000000
#
#            Class 6  Class 7    Class 8    Class 9  ...  Class 75   Class 76  \
# precision   0.9375      1.0   0.828571   1.000000  ...       1.0   0.956522
# recall      0.9375      1.0   0.852941   0.840000  ...       1.0   0.785714
# f1-score    0.9375      1.0   0.840580   0.913043  ...       1.0   0.862745
# support    32.0000     47.0  34.000000  25.000000  ...      35.0  28.000000
#
#            Class 77   Class 78   Class 79   Class 80  Class 81  accuracy  \
# precision   0.73913   0.965517   0.960000   0.916667  0.636364  0.897424
# recall      0.62963   0.875000   0.923077   1.000000  0.777778  0.897424
# f1-score    0.68000   0.918033   0.941176   0.956522  0.700000  0.897424
# support    27.00000  32.000000  26.000000  22.000000  9.000000  0.897424
#
#              macro avg  weighted avg
# precision     0.880224      0.905416
# recall        0.893791      0.897424
# f1-score      0.883140      0.898829
# support    2096.000000   2096.000000
#
# [4 rows x 85 columns]
