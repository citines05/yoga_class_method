# %%
import os

os.environ['TF_CPP_MIN_LOG_LEVEL'] = '2'

def check_and_install(package_name):
    try:
        __import__(package_name)
    except ImportError:
        os.system(f'pip install {package_name}')

check_and_install('gdown')

import matplotlib.pyplot as plt
import pathlib
from collections import defaultdict
import numpy as np
import pandas as pd
import seaborn as sns
from sklearn.metrics import confusion_matrix, classification_report

import tensorflow as tf
from tensorflow import keras
from keras.models import load_model
from tensorflow.keras import layers
from tensorflow.keras.regularizers import L2
from tensorflow.keras.initializers import HeUniform
from tensorflow.keras.callbacks import LearningRateScheduler, ModelCheckpoint, EarlyStopping

# %% [markdown]
# # Dataset visualization

# %%
def count_files_in_all_splits(dataset_path):
    """
    Counts the number of files in each class for the train, test, and valid directories.

    :param dataset_path: Path to the dataset (main directory).
    :return: Dictionary with the class name as the key and the number of files per split as values.
    """
    splits = ['train', 'test', 'valid']  # Main subdirectories
    class_counts = defaultdict(lambda: {'train': 0, 'test': 0, 'valid': 0})

    for split in splits:
        split_path = dataset_path / split
        if not split_path.exists():
            print(f"Subdirectory {split} not found in {dataset_path}")
            continue

        for class_name in os.listdir(split_path):
            class_path = split_path / class_name
            if class_path.is_dir():
                # Count the files in the class folder
                file_count = len([f for f in class_path.iterdir() if f.is_file()])
                class_counts[class_name][split] = file_count

    return class_counts

# Path to the dataset
dataset_path = pathlib.Path('kp_ds_aug_2')  # Modify to the correct path

# Download and unzip the dataset, if necessary
if not dataset_path.exists():
    os.system('gdown 1Fjc-yTP9ovibz9QpECEY2uwonbroZQ1e -O dataset_keypoints_yoga.zip') # Drive ID
    os.system('unzip -q dataset_keypoints_yoga.zip')

# Count files in each class
class_file_counts = count_files_in_all_splits(dataset_path)

# Map classes to numbered names
class_name_map = {cls: f"Class {i}" for i, cls in enumerate(class_file_counts)}

# Generate histograms for each split with classes sorted in descending order by file count
for split in ['train', 'test', 'valid']:
    # Sort classes alphabetically to get the mapping
    sorted_class_names = sorted(class_file_counts.keys())  # Alphabetical order
    class_name_map = {cls: f"Class {i}" for i, cls in enumerate(sorted_class_names)}  # Numeric mapping

    # Sort classes by the number of files in the current subset
    sorted_classes_by_count = sorted(class_file_counts.items(), key=lambda x: x[1][split], reverse=True)

    # Map labels to the format "Class X (real_name)"
    classes = [class_name_map[cls] for cls, _ in sorted_classes_by_count]
    file_counts = [counts[split] for _, counts in sorted_classes_by_count]

    # Generate the histogram
    plt.figure(figsize=(12, 6))
    plt.bar(classes, file_counts, edgecolor='black', alpha=0.7)
    plt.xlabel("Classes")
    plt.ylabel(f"Number of Files ({split.capitalize()})")
    plt.title(f"File Distribution by Class - {split.capitalize()}")
    plt.xticks(rotation=90)  # Rotate class names for better readability
    plt.tight_layout()  # Adjust layout to avoid overlap
    plt.show()

sorted_class_names = sorted(class_file_counts.keys())  # Sort real class names alphabetically
class_name_map = {cls: f"Class {i}" for i, cls in enumerate(sorted_class_names)}

# Display total counts with numbered and real names in alphabetical order
print("\nTotal count per class with numbered and real names (alphabetical order):")
for class_name in sorted_class_names:
    mapped_name = class_name_map[class_name]
    counts = class_file_counts[class_name]
    total = sum(counts.values())
    print(f"{mapped_name} ({class_name}): Train={counts['train']}, Test={counts['test']}, Valid={counts['valid']}, Total={total}")
# Out:
# Contagem total por classe com nomes numerados e nomes reais (ordem alfabética):
# Class 0 (Akarna_Dhanurasana): Train=74, Test=8, Valid=8, Total=90
# Class 1 (Bharadvaja's_Twist_pose_or_Bharadvajasana_I_): Train=72, Test=10, Valid=9, Total=91
# Class 2 (Boat_Pose_or_Paripurna_Navasana_): Train=382, Test=41, Valid=41, Total=464
# Class 3 (Bound_Angle_Pose_or_Baddha_Konasana_): Train=268, Test=32, Valid=31, Total=331
# Class 4 (Bow_Pose_or_Dhanurasana_): Train=178, Test=21, Valid=21, Total=220
# Class 5 (Bridge_Pose_or_Setu_Bandha_Sarvangasana_): Train=254, Test=25, Valid=25, Total=304
# Class 6 (Camel_Pose_or_Ustrasana_): Train=276, Test=32, Valid=32, Total=340
# Class 7 (Cat_Cow_Pose_or_Marjaryasana_): Train=436, Test=47, Valid=46, Total=529
# Class 8 (Chair_Pose_or_Utkatasana_): Train=318, Test=34, Valid=33, Total=385
# Class 9 (Child_Pose_or_Balasana_): Train=256, Test=25, Valid=24, Total=305
# Class 10 (Cobra_Pose_or_Bhujangasana_): Train=810, Test=82, Valid=81, Total=973
# Class 11 (Cockerel_Pose): Train=160, Test=14, Valid=13, Total=187
# Class 12 (Corpse_Pose_or_Savasana_): Train=296, Test=34, Valid=34, Total=364
# Class 13 (Cow_Face_Pose_or_Gomukhasana_): Train=310, Test=32, Valid=31, Total=373
# Class 14 (Crane_(Crow)_Pose_or_Bakasana_): Train=304, Test=29, Valid=28, Total=361
# Class 15 (Dolphin_Plank_Pose_or_Makara_Adho_Mukha_Svanasana_): Train=52, Test=4, Valid=4, Total=60
# Class 16 (Dolphin_Pose_or_Ardha_Pincha_Mayurasana_): Train=62, Test=6, Valid=5, Total=73
# Class 17 (Downward-Facing_Dog_pose_or_Adho_Mukha_Svanasana_): Train=272, Test=31, Valid=30, Total=333
# Class 18 (Eagle_Pose_or_Garudasana_): Train=326, Test=32, Valid=32, Total=390
# Class 19 (Eight-Angle_Pose_or_Astavakrasana_): Train=176, Test=20, Valid=19, Total=215
# Class 20 (Extended_Puppy_Pose_or_Uttana_Shishosana_): Train=80, Test=8, Valid=7, Total=95
# Class 21 (Extended_Revolved_Side_Angle_Pose_or_Utthita_Parsvakonasana_): Train=586, Test=65, Valid=65, Total=716
# Class 22 (Extended_Revolved_Triangle_Pose_or_Utthita_Trikonasana_): Train=572, Test=63, Valid=63, Total=698
# Class 23 (Feathered_Peacock_Pose_or_Pincha_Mayurasana_): Train=218, Test=26, Valid=26, Total=270
# Class 24 (Firefly_Pose_or_Tittibhasana_): Train=198, Test=19, Valid=18, Total=235
# Class 25 (Fish_Pose_or_Matsyasana_): Train=284, Test=30, Valid=29, Total=343
# Class 26 (Four-Limbed_Staff_Pose_or_Chaturanga_Dandasana_): Train=228, Test=26, Valid=25, Total=279
# Class 27 (Frog_Pose_or_Bhekasana): Train=162, Test=18, Valid=17, Total=197
# Class 28 (Garland_Pose_or_Malasana_): Train=248, Test=21, Valid=21, Total=290
# Class 29 (Gate_Pose_or_Parighasana_): Train=178, Test=17, Valid=17, Total=212
# Class 30 (Half_Lord_of_the_Fishes_Pose_or_Ardha_Matsyendrasana_): Train=352, Test=38, Valid=37, Total=427
# Class 31 (Half_Moon_Pose_or_Ardha_Chandrasana_): Train=286, Test=32, Valid=31, Total=349
# Class 32 (Handstand_pose_or_Adho_Mukha_Vrksasana_): Train=204, Test=23, Valid=23, Total=250
# Class 33 (Happy_Baby_Pose_or_Ananda_Balasana_): Train=152, Test=15, Valid=15, Total=182
# Class 34 (Head-to-Knee_Forward_Bend_pose_or_Janu_Sirsasana_): Train=168, Test=17, Valid=17, Total=202
# Class 35 (Heron_Pose_or_Krounchasana_): Train=150, Test=15, Valid=15, Total=180
# Class 36 (Intense_Side_Stretch_Pose_or_Parsvottanasana_): Train=180, Test=21, Valid=20, Total=221
# Class 37 (Legs-Up-the-Wall_Pose_or_Viparita_Karani_): Train=202, Test=24, Valid=24, Total=250
# Class 38 (Locust_Pose_or_Salabhasana_): Train=228, Test=24, Valid=24, Total=276
# Class 39 (Lord_of_the_Dance_Pose_or_Natarajasana_): Train=432, Test=47, Valid=46, Total=525
# Class 40 (Low_Lunge_pose_or_Anjaneyasana_): Train=284, Test=32, Valid=31, Total=347
# Class 41 (Noose_Pose_or_Pasasana_): Train=42, Test=4, Valid=4, Total=50
# Class 42 (Peacock_Pose_or_Mayurasana_): Train=126, Test=15, Valid=14, Total=155
# Class 43 (Pigeon_Pose_or_Kapotasana_): Train=28, Test=5, Valid=5, Total=38
# Class 44 (Plank_Pose_or_Kumbhakasana_): Train=78, Test=8, Valid=8, Total=94
# Class 45 (Plow_Pose_or_Halasana_): Train=260, Test=26, Valid=26, Total=312
# Class 46 (Pose_Dedicated_to_the_Sage_Koundinya_or_Eka_Pada_Koundinyanasana_I_and_II): Train=146, Test=16, Valid=15, Total=177
# Class 47 (Rajakapotasana): Train=250, Test=26, Valid=25, Total=301
# Class 48 (Reclining_Hand-to-Big-Toe_Pose_or_Supta_Padangusthasana_): Train=168, Test=17, Valid=16, Total=201
# Class 49 (Revolved_Head-to-Knee_Pose_or_Parivrtta_Janu_Sirsasana_): Train=230, Test=29, Valid=28, Total=287
# Class 50 (Scale_Pose_or_Tolasana_): Train=148, Test=17, Valid=16, Total=181
# Class 51 (Scorpion_pose_or_vrischikasana): Train=236, Test=24, Valid=23, Total=283
# Class 52 (Seated_Forward_Bend_pose_or_Paschimottanasana_): Train=282, Test=28, Valid=28, Total=338
# Class 53 (Shoulder-Pressing_Pose_or_Bhujapidasana_): Train=102, Test=11, Valid=10, Total=123
# Class 54 (Side-Reclining_Leg_Lift_pose_or_Anantasana_): Train=74, Test=7, Valid=7, Total=88
# Class 55 (Side_Crane_(Crow)_Pose_or_Parsva_Bakasana_): Train=184, Test=21, Valid=21, Total=226
# Class 56 (Side_Plank_Pose_or_Vasisthasana_): Train=346, Test=36, Valid=36, Total=418
# Class 57 (Sitting pose 1 (normal)): Train=706, Test=77, Valid=76, Total=859
# Class 58 (Split pose): Train=346, Test=36, Valid=36, Total=418
# Class 59 (Staff_Pose_or_Dandasana_): Train=88, Test=7, Valid=7, Total=102
# Class 60 (Standing_Forward_Bend_pose_or_Uttanasana_): Train=354, Test=41, Valid=41, Total=436
# Class 61 (Standing_Split_pose_or_Urdhva_Prasarita_Eka_Padasana_): Train=162, Test=15, Valid=14, Total=191
# Class 62 (Standing_big_toe_hold_pose_or_Utthita_Padangusthasana): Train=200, Test=22, Valid=21, Total=243
# Class 63 (Supported_Headstand_pose_or_Salamba_Sirsasana_): Train=324, Test=37, Valid=36, Total=397
# Class 64 (Supported_Shoulderstand_pose_or_Salamba_Sarvangasana_): Train=232, Test=27, Valid=26, Total=285
# Class 65 (Supta_Baddha_Konasana_): Train=336, Test=38, Valid=38, Total=412
# Class 66 (Supta_Virasana_Vajrasana): Train=300, Test=30, Valid=29, Total=359
# Class 67 (Tortoise_Pose): Train=98, Test=10, Valid=9, Total=117
# Class 68 (Tree_Pose_or_Vrksasana_): Train=268, Test=30, Valid=29, Total=327
# Class 69 (Upward_Bow_(Wheel)_Pose_or_Urdhva_Dhanurasana_): Train=104, Test=10, Valid=9, Total=123
# Class 70 (Upward_Facing_Two-Foot_Staff_Pose_or_Dwi_Pada_Viparita_Dandasana_): Train=44, Test=10, Valid=10, Total=64
# Class 71 (Upward_Plank_Pose_or_Purvottanasana_): Train=262, Test=25, Valid=24, Total=311
# Class 72 (Viparita_virabhadrasana_or_reverse_warrior_pose): Train=204, Test=15, Valid=15, Total=234
# Class 73 (Virasana_or_Vajrasana): Train=396, Test=42, Valid=41, Total=479
# Class 74 (Warrior_III_Pose_or_Virabhadrasana_III_): Train=234, Test=15, Valid=15, Total=264
# Class 75 (Warrior_II_Pose_or_Virabhadrasana_II_): Train=336, Test=35, Valid=34, Total=405
# Class 76 (Warrior_I_Pose_or_Virabhadrasana_I_): Train=172, Test=28, Valid=28, Total=228
# Class 77 (Wide-Angle_Seated_Forward_Bend_pose_or_Upavistha_Konasana_): Train=226, Test=27, Valid=26, Total=279
# Class 78 (Wide-Legged_Forward_Bend_pose_or_Prasarita_Padottanasana_): Train=290, Test=32, Valid=31, Total=353
# Class 79 (Wild_Thing_pose_or_Camatkarasana_): Train=206, Test=26, Valid=26, Total=258
# Class 80 (Wind_Relieving_pose_or_Pawanmuktasana): Train=190, Test=22, Valid=22, Total=234
# Class 81 (Yogic_sleep_pose): Train=56, Test=9, Valid=8, Total=73

# %%
train_counts = {cls: counts['train'] for cls, counts in class_file_counts.items()}
sorted_train_classes = sorted(train_counts.items(), key=lambda x: x[1], reverse=True)

# Select the top 10 classes with the largest amount of training data
top_classes = sorted_train_classes[:10]

# Display histograms only for the top 10 classes with the most data in the "train" split
top_class_names = [cls for cls, _ in top_classes]
file_counts = [class_file_counts[cls]['train'] for cls in top_class_names]

plt.figure(figsize=(12, 6))
plt.bar(top_class_names, file_counts, edgecolor='black', alpha=0.7)
plt.xlabel("Classes")
plt.ylabel("Number of Files (Train)")
plt.title("File Distribution in Classes with the Largest Amount of Training Data")
plt.xticks(rotation=90)  # Rotate class names for better readability
plt.tight_layout()  # Adjust layout to avoid overlap
plt.show()

print("\nNumber of training files in selected classes:")
for cls, count in zip(top_class_names, file_counts):
    print(f"{cls}: {count}")
# Out:
# Number of training files in selected classes:
# Cobra_Pose_or_Bhujangasana_: 810
# Sitting pose 1 (normal): 706
# Extended_Revolved_Side_Angle_Pose_or_Utthita_Parsvakonasana_: 586
# Extended_Revolved_Triangle_Pose_or_Utthita_Trikonasana_: 572
# Cat_Cow_Pose_or_Marjaryasana_: 436
# Lord_of_the_Dance_Pose_or_Natarajasana_: 432
# Virasana_or_Vajrasana: 396
# Boat_Pose_or_Paripurna_Navasana_: 382
# Standing_Forward_Bend_pose_or_Uttanasana_: 354
# Half_Lord_of_the_Fishes_Pose_or_Ardha_Matsyendrasana_: 352

# %% [markdown]
# # Dataset preprocessing

# %%
train_ds = tf.data.Dataset.list_files(str(dataset_path/'train/*/*.npy'), shuffle=True)

val_ds = tf.data.Dataset.list_files(str(dataset_path/'valid/*/*.npy'), shuffle=False)

test_ds = tf.data.Dataset.list_files(str(dataset_path/'test/*/*.npy'), shuffle=False)

# %%
def count_elements(dataset):
    count = 0
    for _ in dataset:
        count += 1
    return count

train_ds_count = count_elements(train_ds)
val_ds_count = count_elements(val_ds)
test_ds_count = count_elements(test_ds)

print(f"Tamanho do train_ds: {train_ds_count}")
print(f"Tamanho do val_ds: {val_ds_count}")
print(f"Tamanho do test_ds: {test_ds_count}")
# Out:
# Tamanho do train_ds: 19508
# Tamanho do val_ds: 2051
# Tamanho do test_ds: 2096

# %%
for f in train_ds.take(5):
    print(f.numpy())
# Out:
# b'kp_ds_aug_2/train/Low_Lunge_pose_or_Anjaneyasana_/flipped_233.npy'
# b'kp_ds_aug_2/train/Frog_Pose_or_Bhekasana/flipped_1_84.npy'
# b'kp_ds_aug_2/train/Supta_Baddha_Konasana_/flipped_3_256.npy'
# b'kp_ds_aug_2/train/Crane_(Crow)_Pose_or_Bakasana_/1_161.npy'
# b'kp_ds_aug_2/train/Firefly_Pose_or_Tittibhasana_/flipped_279.npy'

# %%
class_names = np.array(sorted([item.name for item in dataset_path.glob('train/*')]))
class_names
# Out:
# array(['Akarna_Dhanurasana',
#        "Bharadvaja's_Twist_pose_or_Bharadvajasana_I_",
#        'Boat_Pose_or_Paripurna_Navasana_',
#        'Bound_Angle_Pose_or_Baddha_Konasana_', 'Bow_Pose_or_Dhanurasana_',
#        'Bridge_Pose_or_Setu_Bandha_Sarvangasana_',
#        'Camel_Pose_or_Ustrasana_', 'Cat_Cow_Pose_or_Marjaryasana_',
#        'Chair_Pose_or_Utkatasana_', 'Child_Pose_or_Balasana_',
#        'Cobra_Pose_or_Bhujangasana_', 'Cockerel_Pose',
#        'Corpse_Pose_or_Savasana_', 'Cow_Face_Pose_or_Gomukhasana_',
#        'Crane_(Crow)_Pose_or_Bakasana_',
#        'Dolphin_Plank_Pose_or_Makara_Adho_Mukha_Svanasana_',
#        'Dolphin_Pose_or_Ardha_Pincha_Mayurasana_',
#        'Downward-Facing_Dog_pose_or_Adho_Mukha_Svanasana_',
#        'Eagle_Pose_or_Garudasana_', 'Eight-Angle_Pose_or_Astavakrasana_',
#        'Extended_Puppy_Pose_or_Uttana_Shishosana_',
#        'Extended_Revolved_Side_Angle_Pose_or_Utthita_Parsvakonasana_',
#        'Extended_Revolved_Triangle_Pose_or_Utthita_Trikonasana_',
#        'Feathered_Peacock_Pose_or_Pincha_Mayurasana_',
#        'Firefly_Pose_or_Tittibhasana_', 'Fish_Pose_or_Matsyasana_',
#        'Four-Limbed_Staff_Pose_or_Chaturanga_Dandasana_',
#        'Frog_Pose_or_Bhekasana', 'Garland_Pose_or_Malasana_',
#        'Gate_Pose_or_Parighasana_',
#        'Half_Lord_of_the_Fishes_Pose_or_Ardha_Matsyendrasana_',
#        'Half_Moon_Pose_or_Ardha_Chandrasana_',
#        'Handstand_pose_or_Adho_Mukha_Vrksasana_',
#        'Happy_Baby_Pose_or_Ananda_Balasana_',
#        'Head-to-Knee_Forward_Bend_pose_or_Janu_Sirsasana_',
#        'Heron_Pose_or_Krounchasana_',
#        'Intense_Side_Stretch_Pose_or_Parsvottanasana_',
#        'Legs-Up-the-Wall_Pose_or_Viparita_Karani_',
#        'Locust_Pose_or_Salabhasana_',
#        'Lord_of_the_Dance_Pose_or_Natarajasana_',
#        'Low_Lunge_pose_or_Anjaneyasana_', 'Noose_Pose_or_Pasasana_',
#        'Peacock_Pose_or_Mayurasana_', 'Pigeon_Pose_or_Kapotasana_',
#        'Plank_Pose_or_Kumbhakasana_', 'Plow_Pose_or_Halasana_',
#        'Pose_Dedicated_to_the_Sage_Koundinya_or_Eka_Pada_Koundinyanasana_I_and_II',
#        'Rajakapotasana',
#        'Reclining_Hand-to-Big-Toe_Pose_or_Supta_Padangusthasana_',
#        'Revolved_Head-to-Knee_Pose_or_Parivrtta_Janu_Sirsasana_',
#        'Scale_Pose_or_Tolasana_', 'Scorpion_pose_or_vrischikasana',
#        'Seated_Forward_Bend_pose_or_Paschimottanasana_',
#        'Shoulder-Pressing_Pose_or_Bhujapidasana_',
#        'Side-Reclining_Leg_Lift_pose_or_Anantasana_',
#        'Side_Crane_(Crow)_Pose_or_Parsva_Bakasana_',
#        'Side_Plank_Pose_or_Vasisthasana_', 'Sitting pose 1 (normal)',
#        'Split pose', 'Staff_Pose_or_Dandasana_',
#        'Standing_Forward_Bend_pose_or_Uttanasana_',
#        'Standing_Split_pose_or_Urdhva_Prasarita_Eka_Padasana_',
#        'Standing_big_toe_hold_pose_or_Utthita_Padangusthasana',
#        'Supported_Headstand_pose_or_Salamba_Sirsasana_',
#        'Supported_Shoulderstand_pose_or_Salamba_Sarvangasana_',
#        'Supta_Baddha_Konasana_', 'Supta_Virasana_Vajrasana',
#        'Tortoise_Pose', 'Tree_Pose_or_Vrksasana_',
#        'Upward_Bow_(Wheel)_Pose_or_Urdhva_Dhanurasana_',
#        'Upward_Facing_Two-Foot_Staff_Pose_or_Dwi_Pada_Viparita_Dandasana_',
#        'Upward_Plank_Pose_or_Purvottanasana_',
#        'Viparita_virabhadrasana_or_reverse_warrior_pose',
#        'Virasana_or_Vajrasana', 'Warrior_III_Pose_or_Virabhadrasana_III_',
#        'Warrior_II_Pose_or_Virabhadrasana_II_',
#        'Warrior_I_Pose_or_Virabhadrasana_I_',
#        'Wide-Angle_Seated_Forward_Bend_pose_or_Upavistha_Konasana_',
#        'Wide-Legged_Forward_Bend_pose_or_Prasarita_Padottanasana_',
#        'Wild_Thing_pose_or_Camatkarasana_',
#        'Wind_Relieving_pose_or_Pawanmuktasana', 'Yogic_sleep_pose'],
#       dtype='<U73')

# %%
num_classes = len(class_names)
num_classes
# Out:
# 82

# %% [markdown]
# ## `tf.data` preprocessing

# %%
def get_label(file_path):
    """
    Retrieves the label (class) from the file path.
    """
    parts = tf.strings.split(file_path, os.path.sep)
    one_hot = parts[-2] == class_names
    return tf.argmax(one_hot)

def decode_npy(file_path):
    """
    Loads data from a .npy file.
    """
    # Using tf.numpy_function to load the .npy file with numpy
    def load_npy(path):
        return np.load(path.decode('utf-8')).astype(np.float32)

    # Convert the path to a tensor using numpy_function
    npy_data = tf.numpy_function(load_npy, [file_path], tf.float32)
    npy_data.set_shape([33, 4])
    return npy_data

def process_path(file_path, label=None):
    """
    Processes the file path to obtain data and labels.
    """
    label = get_label(file_path)  # Retrieve label
    data = decode_npy(file_path)  # Load data from the .npy file
    return data, label

# %%
# Dataset mapping
train_ds = train_ds.map(process_path, num_parallel_calls=tf.data.AUTOTUNE)
val_ds = val_ds.map(process_path, num_parallel_calls=tf.data.AUTOTUNE)
test_ds = test_ds.map(process_path, num_parallel_calls=tf.data.AUTOTUNE)

# %%
for input_batch, label_batch in train_ds.take(1):
    print(input_batch.shape)
    print(label_batch.numpy())
# Out:
# (33, 4)
# 40

# %%
def configure_for_performance(ds, shuffle=False):
    """
    Configures the dataset for better performance during training.
    """
    ds = ds.cache()
    if shuffle:
        ds = ds.shuffle(buffer_size=1000)
    ds = ds.batch(32)
    ds = ds.prefetch(buffer_size=tf.data.AUTOTUNE)
    return ds

# %%
train_ds = configure_for_performance(train_ds, shuffle=True)
val_ds = configure_for_performance(val_ds, shuffle=False)
test_ds = configure_for_performance(test_ds, shuffle=False)

# %% [markdown]
# # Transformer with CNN extraction

# %% [markdown]
# ## Transformer Encoder

# %%
init = HeUniform(seed=42)
reg1 = L2(1e-4)
reg2 = L2(1e-5)

# %%
@tf.keras.utils.register_keras_serializable()
class TransformerEncoder(layers.Layer):
  def __init__(self, num_heads, conv_dim, name, **kwargs):
    super(TransformerEncoder, self).__init__(name=name, **kwargs)

    self.num_heads = num_heads
    self.conv_dim = conv_dim

    self.layer_norm = layers.LayerNormalization()
    self.mha = layers.MultiHeadAttention(self.num_heads, self.conv_dim,
                                         kernel_initializer=init)
    self.conv_proj = tf.keras.Sequential([
        layers.Dense(self.conv_dim, activation='relu', kernel_regularizer=reg1, bias_regularizer=reg1, activity_regularizer=reg2),
        layers.Dense(self.conv_dim, activation='relu', kernel_regularizer=reg1, bias_regularizer=reg1, activity_regularizer=reg2),
        layers.Dense(self.conv_dim, kernel_regularizer=reg1, bias_regularizer=reg1, activity_regularizer=reg2)
    ])

  def build(self, input_shape):
    super(TransformerEncoder, self).build(input_shape)

  def call(self, inputs):
    attention_output = self.mha(query=inputs, value=inputs, key=inputs)
    proj_input = self.layer_norm(inputs + attention_output)
    proj_output = self.conv_proj(proj_input)
    return self.layer_norm(proj_input + proj_output)

  def get_config(self):
    config = super().get_config()
    config.update({
        "num_heads": self.mha.num_heads,
        "conv_dim": self.mha.key_dim,
    })
    return config

# %% [markdown]
# ## Model architecture

# %%
input_shape = (33, 4)

inputs = tf.keras.Input(shape=input_shape)
x = layers.MultiHeadAttention(num_heads=4, key_dim=16)(inputs, inputs)
x = inputs + x
x = layers.Conv1D(filters=80, kernel_size=5, padding="same")(x)
x = layers.BatchNormalization()(x)
x = layers.Activation('relu')(x)
x = layers.Conv1D(filters=48, kernel_size=5, padding="same", kernel_regularizer=reg1)(x)
x = layers.BatchNormalization()(x)
x = layers.Activation('relu')(x)
x = layers.Dropout(0.25)(x)
x = layers.Conv1D(filters=16, kernel_size=5, padding="same", kernel_regularizer=reg1, bias_regularizer=reg1, activity_regularizer=reg2)(x)
x = layers.BatchNormalization()(x)
x = layers.Activation('relu')(x)
x = TransformerEncoder(num_heads=4, conv_dim=16, name='transformer_encoder')(x)
x = layers.Flatten()(x)
x = layers.Dense(88, activation='relu', kernel_regularizer=reg1, bias_regularizer=reg1, activity_regularizer=reg2)(x)
x = layers.Dropout(0.5)(x)
# x = layers.Dense(88, activation='relu', kernel_regularizer=reg1, bias_regularizer=reg1, activity_regularizer=reg2)(x)
# x = layers.Dropout(0.25)(x)
outputs = layers.Dense(num_classes, activation='softmax')(x)

transformer = keras.Model(inputs=inputs, outputs=outputs)

# %%
transformer.summary()
# Out:
# Model: "functional_33"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)              ┃ Output Shape           ┃        Param # ┃ Connected to           ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_33            │ (None, 33, 4)          │              0 │ -                      │
# │ (InputLayer)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ multi_head_attention_33   │ (None, 33, 4)          │          1,220 │ input_layer_33[0][0],  │
# │ (MultiHeadAttention)      │                        │                │ input_layer_33[0][0]   │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ add_12 (Add)              │ (None, 33, 4)          │              0 │ input_layer_33[0][0],  │
# │                           │                        │                │ multi_head_attention_… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv1d_36 (Conv1D)        │ (None, 33, 80)         │          1,680 │ add_12[0][0]           │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_35    │ (None, 33, 80)         │            320 │ conv1d_36[0][0]        │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ activation_35             │ (None, 33, 80)         │              0 │ batch_normalization_3… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv1d_37 (Conv1D)        │ (None, 33, 48)         │         19,248 │ activation_35[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_36    │ (None, 33, 48)         │            192 │ conv1d_37[0][0]        │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ activation_36             │ (None, 33, 48)         │              0 │ batch_normalization_3… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dropout_62 (Dropout)      │ (None, 33, 48)         │              0 │ activation_36[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv1d_38 (Conv1D)        │ (None, 33, 16)         │          3,856 │ dropout_62[0][0]       │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_37    │ (None, 33, 16)         │             64 │ conv1d_38[0][0]        │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ activation_37             │ (None, 33, 16)         │              0 │ batch_normalization_3… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ transformer_encoder       │ (None, 33, 16)         │          5,152 │ activation_37[0][0]    │
# │ (TransformerEncoder)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ flatten_11 (Flatten)      │ (None, 528)            │              0 │ transformer_encoder[0… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_88 (Dense)          │ (None, 88)             │         46,552 │ flatten_11[0][0]       │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dropout_64 (Dropout)      │ (None, 88)             │              0 │ dense_88[0][0]         │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_89 (Dense)          │ (None, 82)             │          7,298 │ dropout_64[0][0]       │
# └───────────────────────────┴────────────────────────┴────────────────┴────────────────────────┘
#  Total params: 85,582 (334.30 KB)
#  Trainable params: 85,294 (333.18 KB)
#  Non-trainable params: 288 (1.12 KB)

# %% [markdown]
# ## Model training

# %%
def scheduler(epoch, lr):
  if epoch < 20:
    return lr
  else:
    return lr * float(tf.math.exp(-0.1))

callbacks = [
    ModelCheckpoint(filepath='kp_ds_aug_2_model_1_tranformer_cnn.keras',
                    save_best_only=True,
                    monitor='val_accuracy',
                    verbose=1),
    LearningRateScheduler(scheduler),
    EarlyStopping(monitor='val_accuracy', patience=15, restore_best_weights=True)
]

# %%
transformer.compile(optimizer=tf.keras.optimizers.AdamW(learning_rate=1e-3),
            loss=tf.keras.losses.SparseCategoricalCrossentropy(),
            metrics=['accuracy'])

# %%
history = transformer.fit(
    train_ds,
    epochs=150,
    validation_data=val_ds,
    callbacks=callbacks)
# Out:
# Epoch 1/150
# 610/610 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.2178 - loss: 3.5664
# Epoch 1: val_accuracy improved from -inf to 0.71916, saving model to kp_ds_aug_2_model_1_tranformer_cnn.keras
# 610/610 ━━━━━━━━━━━━━━━━━━━━ 38s 39ms/step - accuracy: 0.2181 - loss: 3.5650 - val_accuracy: 0.7192 - val_loss: 1.1756 - learning_rate: 0.0010
# Epoch 2/150
# 601/610 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6099 - loss: 1.5825
# Epoch 2: val_accuracy improved from 0.71916 to 0.79132, saving model to kp_ds_aug_2_model_1_tranformer_cnn.keras
# 610/610 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.6103 - loss: 1.5807 - val_accuracy: 0.7913 - val_loss: 0.8738 - learning_rate: 0.0010
# Epoch 3/150
# 598/610 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7003 - loss: 1.2466
# Epoch 3: val_accuracy improved from 0.79132 to 0.81570, saving model to kp_ds_aug_2_model_1_tranformer_cnn.keras
# 610/610 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.7004 - loss: 1.2460 - val_accuracy: 0.8157 - val_loss: 0.8080 - learning_rate: 0.0010
# Epoch 4/150
# 610/610 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7391 - loss: 1.0773
# Epoch 4: val_accuracy improved from 0.81570 to 0.82691, saving model to kp_ds_aug_2_model_1_tranformer_cnn.keras
# 610/610 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.7391 - loss: 1.0773 - val_accuracy: 0.8269 - val_loss: 0.7614 - learning_rate: 0.0010
# Epoch 5/150
# 610/610 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7705 - loss: 0.9784
# Epoch 5: val_accuracy improved from 0.82691 to 0.83764, saving model to kp_ds_aug_2_model_1_tranformer_cnn.keras
# 610/610 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.7705 - loss: 0.9784 - val_accuracy: 0.8376 - val_loss: 0.7107 - learning_rate: 0.0010
# Epoch 6/150
# 609/610 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7797 - loss: 0.9282
# Epoch 6: val_accuracy improved from 0.83764 to 0.85471, saving model to kp_ds_aug_2_model_1_tranformer_cnn.keras
# 610/610 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.7797 - loss: 0.9282 - val_accuracy: 0.8547 - val_loss: 0.6717 - learning_rate: 0.0010
# Epoch 7/150
# 599/610 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7924 - loss: 0.8815
# Epoch 7: val_accuracy improved from 0.85471 to 0.85958, saving model to kp_ds_aug_2_model_1_tranformer_cnn.keras
# 610/610 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.7923 - loss: 0.8816 - val_accuracy: 0.8596 - val_loss: 0.6220 - learning_rate: 0.0010
# Epoch 8/150
# 608/610 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8069 - loss: 0.8214
# Epoch 8: val_accuracy improved from 0.85958 to 0.87031, saving model to kp_ds_aug_2_model_1_tranformer_cnn.keras
# 610/610 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.8069 - loss: 0.8215 - val_accuracy: 0.8703 - val_loss: 0.6030 - learning_rate: 0.0010
# Epoch 9/150
# 609/610 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8172 - loss: 0.7924
# Epoch 9: val_accuracy did not improve from 0.87031
# 610/610 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.8172 - loss: 0.7924 - val_accuracy: 0.8537 - val_loss: 0.6440 - learning_rate: 0.0010
# Epoch 10/150
# 604/610 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8155 - loss: 0.7802
# Epoch 10: val_accuracy did not improve from 0.87031
# 610/610 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.8155 - loss: 0.7803 - val_accuracy: 0.8674 - val_loss: 0.6333 - learning_rate: 0.0010
# Epoch 11/150
# 598/610 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8249 - loss: 0.7473
# Epoch 11: val_accuracy did not improve from 0.87031
# 610/610 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.8248 - loss: 0.7477 - val_accuracy: 0.8669 - val_loss: 0.5914 - learning_rate: 0.0010
# Epoch 12/150
# 604/610 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8289 - loss: 0.7245
# Epoch 12: val_accuracy improved from 0.87031 to 0.88055, saving model to kp_ds_aug_2_model_1_tranformer_cnn.keras
# 610/610 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.8289 - loss: 0.7246 - val_accuracy: 0.8805 - val_loss: 0.5730 - learning_rate: 0.0010
# Epoch 13/150
# 608/610 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8388 - loss: 0.7002
# Epoch 13: val_accuracy did not improve from 0.88055
# 610/610 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.8388 - loss: 0.7003 - val_accuracy: 0.8776 - val_loss: 0.6016 - learning_rate: 0.0010
# Epoch 14/150
# 605/610 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8372 - loss: 0.6971
# Epoch 14: val_accuracy did not improve from 0.88055
# 610/610 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.8371 - loss: 0.6973 - val_accuracy: 0.8718 - val_loss: 0.6000 - learning_rate: 0.0010
# Epoch 15/150
# 602/610 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8414 - loss: 0.6715
# Epoch 15: val_accuracy did not improve from 0.88055
# 610/610 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.8414 - loss: 0.6718 - val_accuracy: 0.8737 - val_loss: 0.5902 - learning_rate: 0.0010
# Epoch 16/150
# 600/610 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8376 - loss: 0.6792
# Epoch 16: val_accuracy improved from 0.88055 to 0.88201, saving model to kp_ds_aug_2_model_1_tranformer_cnn.keras
# 610/610 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.8376 - loss: 0.6792 - val_accuracy: 0.8820 - val_loss: 0.5601 - learning_rate: 0.0010
# Epoch 17/150
# 610/610 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8459 - loss: 0.6735
# Epoch 17: val_accuracy improved from 0.88201 to 0.88445, saving model to kp_ds_aug_2_model_1_tranformer_cnn.keras
# 610/610 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.8459 - loss: 0.6735 - val_accuracy: 0.8844 - val_loss: 0.5547 - learning_rate: 0.0010
# Epoch 18/150
# 605/610 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8518 - loss: 0.6426
# Epoch 18: val_accuracy did not improve from 0.88445
# 610/610 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.8518 - loss: 0.6428 - val_accuracy: 0.8781 - val_loss: 0.5745 - learning_rate: 0.0010
# Epoch 19/150
# 605/610 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8511 - loss: 0.6329
# Epoch 19: val_accuracy did not improve from 0.88445
# 610/610 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.8511 - loss: 0.6330 - val_accuracy: 0.8776 - val_loss: 0.5573 - learning_rate: 0.0010
# Epoch 20/150
# 604/610 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8559 - loss: 0.6249
# Epoch 20: val_accuracy did not improve from 0.88445
# 610/610 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.8558 - loss: 0.6251 - val_accuracy: 0.8674 - val_loss: 0.5849 - learning_rate: 0.0010
# Epoch 21/150
# 603/610 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8577 - loss: 0.6169
# Epoch 21: val_accuracy did not improve from 0.88445
# 610/610 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.8577 - loss: 0.6170 - val_accuracy: 0.8820 - val_loss: 0.5522 - learning_rate: 9.0484e-04
# Epoch 22/150
# 599/610 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8663 - loss: 0.5879
# Epoch 22: val_accuracy improved from 0.88445 to 0.88591, saving model to kp_ds_aug_2_model_1_tranformer_cnn.keras
# 610/610 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.8662 - loss: 0.5882 - val_accuracy: 0.8859 - val_loss: 0.5470 - learning_rate: 8.1873e-04
# Epoch 23/150
# 604/610 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8690 - loss: 0.5744
# Epoch 23: val_accuracy did not improve from 0.88591
# 610/610 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.8689 - loss: 0.5744 - val_accuracy: 0.8859 - val_loss: 0.5536 - learning_rate: 7.4082e-04
# Epoch 24/150
# 601/610 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8770 - loss: 0.5515
# Epoch 24: val_accuracy improved from 0.88591 to 0.88640, saving model to kp_ds_aug_2_model_1_tranformer_cnn.keras
# 610/610 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.8769 - loss: 0.5518 - val_accuracy: 0.8864 - val_loss: 0.5382 - learning_rate: 6.7032e-04
# Epoch 25/150
# 601/610 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8764 - loss: 0.5466
# Epoch 25: val_accuracy did not improve from 0.88640
# 610/610 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.8764 - loss: 0.5467 - val_accuracy: 0.8815 - val_loss: 0.5448 - learning_rate: 6.0653e-04
# Epoch 26/150
# 608/610 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8800 - loss: 0.5346
# Epoch 26: val_accuracy improved from 0.88640 to 0.89371, saving model to kp_ds_aug_2_model_1_tranformer_cnn.keras
# 610/610 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.8800 - loss: 0.5346 - val_accuracy: 0.8937 - val_loss: 0.5496 - learning_rate: 5.4881e-04
# Epoch 27/150
# 610/610 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8842 - loss: 0.5171
# Epoch 27: val_accuracy did not improve from 0.89371
# 610/610 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.8842 - loss: 0.5171 - val_accuracy: 0.8937 - val_loss: 0.5127 - learning_rate: 4.9659e-04
# Epoch 28/150
# 600/610 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8884 - loss: 0.4923
# Epoch 28: val_accuracy did not improve from 0.89371
# 610/610 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.8883 - loss: 0.4927 - val_accuracy: 0.8908 - val_loss: 0.5247 - learning_rate: 4.4933e-04
# Epoch 29/150
# 607/610 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8877 - loss: 0.4945
# Epoch 29: val_accuracy improved from 0.89371 to 0.89810, saving model to kp_ds_aug_2_model_1_tranformer_cnn.keras
# 610/610 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.8877 - loss: 0.4946 - val_accuracy: 0.8981 - val_loss: 0.5109 - learning_rate: 4.0657e-04
# Epoch 30/150
# 608/610 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8898 - loss: 0.4818
# Epoch 30: val_accuracy did not improve from 0.89810
# 610/610 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.8898 - loss: 0.4818 - val_accuracy: 0.8976 - val_loss: 0.5204 - learning_rate: 3.6788e-04
# Epoch 31/150
# 608/610 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8903 - loss: 0.4848
# Epoch 31: val_accuracy did not improve from 0.89810
# 610/610 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.8903 - loss: 0.4848 - val_accuracy: 0.8922 - val_loss: 0.5236 - learning_rate: 3.3287e-04
# Epoch 32/150
# 608/610 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8971 - loss: 0.4624
# Epoch 32: val_accuracy did not improve from 0.89810
# 610/610 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.8971 - loss: 0.4625 - val_accuracy: 0.8932 - val_loss: 0.5317 - learning_rate: 3.0119e-04
# Epoch 33/150
# 606/610 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9003 - loss: 0.4534
# Epoch 33: val_accuracy did not improve from 0.89810
# 610/610 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.9002 - loss: 0.4535 - val_accuracy: 0.8947 - val_loss: 0.5263 - learning_rate: 2.7253e-04
# Epoch 34/150
# 601/610 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9022 - loss: 0.4525
# Epoch 34: val_accuracy did not improve from 0.89810
# 610/610 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.9021 - loss: 0.4526 - val_accuracy: 0.8961 - val_loss: 0.5267 - learning_rate: 2.4660e-04
# Epoch 35/150
# 608/610 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9007 - loss: 0.4393
# Epoch 35: val_accuracy did not improve from 0.89810
# 610/610 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.9007 - loss: 0.4394 - val_accuracy: 0.8976 - val_loss: 0.5176 - learning_rate: 2.2313e-04
# Epoch 36/150
# 605/610 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9016 - loss: 0.4364
# Epoch 36: val_accuracy improved from 0.89810 to 0.89907, saving model to kp_ds_aug_2_model_1_tranformer_cnn.keras
# 610/610 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.9016 - loss: 0.4364 - val_accuracy: 0.8991 - val_loss: 0.5165 - learning_rate: 2.0190e-04
# Epoch 37/150
# 605/610 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9017 - loss: 0.4405
# Epoch 37: val_accuracy did not improve from 0.89907
# 610/610 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.9017 - loss: 0.4405 - val_accuracy: 0.8957 - val_loss: 0.5135 - learning_rate: 1.8268e-04
# Epoch 38/150
# 608/610 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9045 - loss: 0.4320
# Epoch 38: val_accuracy did not improve from 0.89907
# 610/610 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.9045 - loss: 0.4320 - val_accuracy: 0.8976 - val_loss: 0.5126 - learning_rate: 1.6530e-04
# Epoch 39/150
# 610/610 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9055 - loss: 0.4215
# Epoch 39: val_accuracy did not improve from 0.89907
# 610/610 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9055 - loss: 0.4215 - val_accuracy: 0.8961 - val_loss: 0.5178 - learning_rate: 1.4957e-04
# Epoch 40/150
# 608/610 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9076 - loss: 0.4159
# Epoch 40: val_accuracy did not improve from 0.89907
# 610/610 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9076 - loss: 0.4159 - val_accuracy: 0.8971 - val_loss: 0.5200 - learning_rate: 1.3534e-04
# Epoch 41/150
# 602/610 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9112 - loss: 0.3990
# Epoch 41: val_accuracy did not improve from 0.89907
# 610/610 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.9112 - loss: 0.3993 - val_accuracy: 0.8966 - val_loss: 0.5163 - learning_rate: 1.2246e-04
# Epoch 42/150
# 610/610 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9090 - loss: 0.4123
# Epoch 42: val_accuracy did not improve from 0.89907
# 610/610 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.9090 - loss: 0.4123 - val_accuracy: 0.8976 - val_loss: 0.5166 - learning_rate: 1.1080e-04
# Epoch 43/150
# 600/610 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9111 - loss: 0.4065
# Epoch 43: val_accuracy did not improve from 0.89907
# 610/610 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.9110 - loss: 0.4066 - val_accuracy: 0.8991 - val_loss: 0.5165 - learning_rate: 1.0026e-04
# Epoch 44/150
# 599/610 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9090 - loss: 0.4089
# Epoch 44: val_accuracy did not improve from 0.89907
# 610/610 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.9091 - loss: 0.4089 - val_accuracy: 0.8976 - val_loss: 0.5118 - learning_rate: 9.0718e-05
# Epoch 45/150
# 610/610 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9082 - loss: 0.4051
# Epoch 45: val_accuracy improved from 0.89907 to 0.89956, saving model to kp_ds_aug_2_model_1_tranformer_cnn.keras
# 610/610 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.9082 - loss: 0.4051 - val_accuracy: 0.8996 - val_loss: 0.5110 - learning_rate: 8.2085e-05
# Epoch 46/150
# 599/610 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9099 - loss: 0.4044
# Epoch 46: val_accuracy did not improve from 0.89956
# 610/610 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.9098 - loss: 0.4045 - val_accuracy: 0.8981 - val_loss: 0.5136 - learning_rate: 7.4273e-05
# Epoch 47/150
# 608/610 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9120 - loss: 0.3951
# Epoch 47: val_accuracy did not improve from 0.89956
# 610/610 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9119 - loss: 0.3952 - val_accuracy: 0.8996 - val_loss: 0.5084 - learning_rate: 6.7205e-05
# Epoch 48/150
# 599/610 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9141 - loss: 0.3884
# Epoch 48: val_accuracy did not improve from 0.89956
# 610/610 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9140 - loss: 0.3887 - val_accuracy: 0.8991 - val_loss: 0.5140 - learning_rate: 6.0810e-05
# Epoch 49/150
# 600/610 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9092 - loss: 0.3948
# Epoch 49: val_accuracy did not improve from 0.89956
# 610/610 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.9092 - loss: 0.3949 - val_accuracy: 0.8986 - val_loss: 0.5110 - learning_rate: 5.5023e-05
# Epoch 50/150
# 601/610 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9107 - loss: 0.3871
# Epoch 50: val_accuracy improved from 0.89956 to 0.90200, saving model to kp_ds_aug_2_model_1_tranformer_cnn.keras
# 610/610 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.9107 - loss: 0.3873 - val_accuracy: 0.9020 - val_loss: 0.5107 - learning_rate: 4.9787e-05
# Epoch 51/150
# 610/610 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9106 - loss: 0.3966
# Epoch 51: val_accuracy did not improve from 0.90200
# 610/610 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9106 - loss: 0.3966 - val_accuracy: 0.8991 - val_loss: 0.5091 - learning_rate: 4.5049e-05
# Epoch 52/150
# 602/610 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9168 - loss: 0.3886
# Epoch 52: val_accuracy did not improve from 0.90200
# 610/610 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9167 - loss: 0.3887 - val_accuracy: 0.8976 - val_loss: 0.5044 - learning_rate: 4.0762e-05
# Epoch 53/150
# 599/610 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9139 - loss: 0.3858
# Epoch 53: val_accuracy did not improve from 0.90200
# 610/610 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.9138 - loss: 0.3859 - val_accuracy: 0.8991 - val_loss: 0.5145 - learning_rate: 3.6883e-05
# Epoch 54/150
# 610/610 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9141 - loss: 0.3894
# Epoch 54: val_accuracy did not improve from 0.90200
# 610/610 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9141 - loss: 0.3894 - val_accuracy: 0.8991 - val_loss: 0.5115 - learning_rate: 3.3373e-05
# Epoch 55/150
# 599/610 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9115 - loss: 0.3901
# Epoch 55: val_accuracy did not improve from 0.90200
# 610/610 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.9115 - loss: 0.3903 - val_accuracy: 0.8991 - val_loss: 0.5114 - learning_rate: 3.0197e-05
# Epoch 56/150
# 606/610 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9117 - loss: 0.3965
# Epoch 56: val_accuracy did not improve from 0.90200
# 610/610 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.9117 - loss: 0.3965 - val_accuracy: 0.8991 - val_loss: 0.5081 - learning_rate: 2.7324e-05
# Epoch 57/150
# 610/610 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9186 - loss: 0.3784
# Epoch 57: val_accuracy did not improve from 0.90200
# 610/610 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9186 - loss: 0.3784 - val_accuracy: 0.8996 - val_loss: 0.5122 - learning_rate: 2.4723e-05
# Epoch 58/150
# 609/610 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9151 - loss: 0.3853
# Epoch 58: val_accuracy did not improve from 0.90200
# 610/610 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.9151 - loss: 0.3853 - val_accuracy: 0.8986 - val_loss: 0.5101 - learning_rate: 2.2371e-05
# Epoch 59/150
# 606/610 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9117 - loss: 0.3862
# Epoch 59: val_accuracy did not improve from 0.90200
# 610/610 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.9117 - loss: 0.3862 - val_accuracy: 0.8981 - val_loss: 0.5104 - learning_rate: 2.0242e-05
# Epoch 60/150
# 601/610 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9115 - loss: 0.3907
# Epoch 60: val_accuracy did not improve from 0.90200
# 610/610 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.9115 - loss: 0.3907 - val_accuracy: 0.8986 - val_loss: 0.5103 - learning_rate: 1.8316e-05
# Epoch 61/150
# 606/610 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9158 - loss: 0.3875
# Epoch 61: val_accuracy did not improve from 0.90200
# 610/610 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.9158 - loss: 0.3875 - val_accuracy: 0.8996 - val_loss: 0.5081 - learning_rate: 1.6573e-05
# Epoch 62/150
# 607/610 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9171 - loss: 0.3766
# Epoch 62: val_accuracy did not improve from 0.90200
# 610/610 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.9171 - loss: 0.3767 - val_accuracy: 0.8981 - val_loss: 0.5070 - learning_rate: 1.4996e-05
# Epoch 63/150
# 606/610 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9153 - loss: 0.3812
# Epoch 63: val_accuracy did not improve from 0.90200
# 610/610 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9152 - loss: 0.3812 - val_accuracy: 0.8976 - val_loss: 0.5079 - learning_rate: 1.3569e-05
# Epoch 64/150
# 603/610 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9151 - loss: 0.3886
# Epoch 64: val_accuracy did not improve from 0.90200
# 610/610 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.9151 - loss: 0.3886 - val_accuracy: 0.8991 - val_loss: 0.5079 - learning_rate: 1.2277e-05
# Epoch 65/150
# 606/610 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9136 - loss: 0.3836
# Epoch 65: val_accuracy did not improve from 0.90200
# 610/610 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9136 - loss: 0.3836 - val_accuracy: 0.9005 - val_loss: 0.5078 - learning_rate: 1.1109e-05

# %% [markdown]
# ## Model metrics

# %%
model = load_model("kp_ds_aug_2_model_1_tranformer_cnn.keras",
                   custom_objects={"TransformerEnconder": TransformerEncoder})

print("Average loss and accuracy during training:")
print(f"loss: {np.average(history.history['loss']):.4f} - accuracy: {np.average(history.history['accuracy']) * 100:.2f}%")

print("Model validation:")
scores = model.evaluate(val_ds, verbose=0)
print(f'loss: {scores[0]:.4f} - accuracy: {scores[1]* 100:.2f}%')

plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model accuracy during training')
plt.ylabel('Accuracy')
plt.xlabel('Epochs')
plt.legend(['Train.', 'Valid.'], loc='lower right')
plt.ylim(0.5, 1.0)
plt.show()

print("\n")

plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss during training')
plt.ylabel('Loss')
plt.xlabel('Epochs')
plt.legend(['Train.', 'Valid.'], loc='upper right')
plt.show()
# Out:
# Average loss and accuracy during training:
# loss: 0.5929 - accuracy: 86.33%
# Model validation:
# loss: 0.5107 - accuracy: 90.20%

# %%
scores = model.evaluate(test_ds, verbose=0)
print("Model testing:")
print(f'loss: {scores[0]:.4f} - accuracy: {scores[1]* 100:.2f}%')
# Out:
# Model testing:
# loss: 0.5364 - accuracy: 90.31%

# %%
mapped_class_names = [class_name_map[cls] for cls in sorted_class_names]  # List of mapped class names

y_pred = np.argmax(model.predict(test_ds), axis=1)  # Get predictions based on probabilities
y_true = np.concatenate([label.numpy() for kp, label in test_ds], axis=0)  # Get true labels
# Out:
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step

# %%
# Confusion matrix plot
cm = confusion_matrix(y_true, y_pred)
plt.figure(figsize=(40, 40))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues',
            xticklabels=mapped_class_names,
            yticklabels=mapped_class_names)
plt.xlabel('Predicted')
plt.ylabel('True')
plt.title('Confusion Matrix')
plt.show()

# %%
# Classification report
report = classification_report(y_true, y_pred, target_names=mapped_class_names, output_dict=True)
report_df = pd.DataFrame(report)
report_df.to_csv("kp_ds_aug_2_report_transformer.csv", index=True)
report_df
# Out:
#             Class 0    Class 1   Class 2    Class 3    Class 4    Class 5  \
# precision  1.000000   0.750000   0.97561   0.966667   0.909091   0.888889
# recall     0.875000   0.600000   0.97561   0.906250   0.952381   0.960000
# f1-score   0.933333   0.666667   0.97561   0.935484   0.930233   0.923077
# support    8.000000  10.000000  41.00000  32.000000  21.000000  25.000000
#
#            Class 6  Class 7    Class 8    Class 9  ...  Class 75   Class 76  \
# precision   0.9375      1.0   0.941176   0.851852  ...       1.0   1.000000
# recall      0.9375      1.0   0.941176   0.920000  ...       1.0   0.785714
# f1-score    0.9375      1.0   0.941176   0.884615  ...       1.0   0.880000
# support    32.0000     47.0  34.000000  25.000000  ...      35.0  28.000000
#
#             Class 77   Class 78   Class 79  Class 80  Class 81  accuracy  \
# precision   0.789474   0.965517   0.913043   0.88000  1.000000  0.903149
# recall      0.555556   0.875000   0.807692   1.00000  0.888889  0.903149
# f1-score    0.652174   0.918033   0.857143   0.93617  0.941176  0.903149
# support    27.000000  32.000000  26.000000  22.00000  9.000000  0.903149
#
#              macro avg  weighted avg
# precision     0.904835      0.907305
# recall        0.886643      0.903149
# f1-score      0.890461      0.902779
# support    2096.000000   2096.000000
#
# [4 rows x 85 columns]
