# %%
import os

os.environ['TF_CPP_MIN_LOG_LEVEL'] = '2'

def check_and_install(package_name):
    try:
        __import__(package_name)
    except ImportError:
        os.system(f'pip install {package_name}')

check_and_install('gdown')

import matplotlib.pyplot as plt
import pathlib
from collections import defaultdict
import numpy as np
import pandas as pd
import seaborn as sns
from sklearn.metrics import confusion_matrix, classification_report

import tensorflow as tf
from tensorflow import keras
from keras.models import load_model
from tensorflow.keras import layers
from tensorflow.keras.regularizers import l2
from tensorflow.keras.initializers import HeUniform
from tensorflow.keras.callbacks import LearningRateScheduler, ModelCheckpoint, EarlyStopping

# %% [markdown]
# # Dataset visualization

# %%
def count_files_in_all_splits(dataset_path):
    """
    Counts the number of files in each class for the train, test, and valid directories.

    :param dataset_path: Path to the dataset (main directory).
    :return: Dictionary with the class name as the key and the number of files per split as values.
    """
    splits = ['train', 'test', 'valid']  # Main subdirectories
    class_counts = defaultdict(lambda: {'train': 0, 'test': 0, 'valid': 0})

    for split in splits:
        split_path = dataset_path / split
        if not split_path.exists():
            print(f"Subdirectory {split} not found in {dataset_path}")
            continue

        for class_name in os.listdir(split_path):
            class_path = split_path / class_name
            if class_path.is_dir():
                # Count the files in the class folder
                file_count = len([f for f in class_path.iterdir() if f.is_file()])
                class_counts[class_name][split] = file_count

    return class_counts

# Path to the dataset
dataset_path = pathlib.Path('kp_ds_not_aug_1')  # Modify to the correct path

# Download and unzip the dataset, if necessary
if not dataset_path.exists():
    os.system('gdown 1W6IaoG9Tvm_NDDZZiQ8Yc9Mc17D-_mfL -O dataset_keypoints_yoga.zip') # Drive ID
    os.system('unzip -q dataset_keypoints_yoga.zip')

# Count files in each class
class_file_counts = count_files_in_all_splits(dataset_path)

# Map classes to numbered names
class_name_map = {cls: f"Class {i}" for i, cls in enumerate(class_file_counts)}

# Generate histograms for each split with classes sorted in descending order by file count
for split in ['train', 'test', 'valid']:
    # Sort classes alphabetically to get the mapping
    sorted_class_names = sorted(class_file_counts.keys())  # Alphabetical order
    class_name_map = {cls: f"Class {i}" for i, cls in enumerate(sorted_class_names)}  # Numeric mapping

    # Sort classes by the number of files in the current subset
    sorted_classes_by_count = sorted(class_file_counts.items(), key=lambda x: x[1][split], reverse=True)

    # Map labels to the format "Class X (real_name)"
    classes = [class_name_map[cls] for cls, _ in sorted_classes_by_count]
    file_counts = [counts[split] for _, counts in sorted_classes_by_count]

    # Generate the histogram
    plt.figure(figsize=(12, 6))
    plt.bar(classes, file_counts, edgecolor='black', alpha=0.7)
    plt.xlabel("Classes")
    plt.ylabel(f"Number of Files ({split.capitalize()})")
    plt.title(f"File Distribution by Class - {split.capitalize()}")
    plt.xticks(rotation=90)  # Rotate class names for better readability
    plt.tight_layout()  # Adjust layout to avoid overlap
    plt.show()

sorted_class_names = sorted(class_file_counts.keys())  # Sort real class names alphabetically
class_name_map = {cls: f"Class {i}" for i, cls in enumerate(sorted_class_names)}

# Display total counts with numbered and real names in alphabetical order
print("\nTotal count per class with numbered and real names (alphabetical order):")
for class_name in sorted_class_names:
    mapped_name = class_name_map[class_name]
    counts = class_file_counts[class_name]
    total = sum(counts.values())
    print(f"{mapped_name} ({class_name}): Train={counts['train']}, Test={counts['test']}, Valid={counts['valid']}, Total={total}")
# Out:
# Contagem total por classe com nomes numerados e nomes reais (ordem alfabética):
# Class 0 (Akarna_Dhanurasana): Train=37, Test=8, Valid=8, Total=53
# Class 1 (Bharadvaja's_Twist_pose_or_Bharadvajasana_I_): Train=36, Test=10, Valid=9, Total=55
# Class 2 (Boat_Pose_or_Paripurna_Navasana_): Train=191, Test=41, Valid=41, Total=273
# Class 3 (Bound_Angle_Pose_or_Baddha_Konasana_): Train=134, Test=32, Valid=31, Total=197
# Class 4 (Bow_Pose_or_Dhanurasana_): Train=89, Test=21, Valid=21, Total=131
# Class 5 (Bridge_Pose_or_Setu_Bandha_Sarvangasana_): Train=127, Test=25, Valid=25, Total=177
# Class 6 (Camel_Pose_or_Ustrasana_): Train=138, Test=32, Valid=32, Total=202
# Class 7 (Cat_Cow_Pose_or_Marjaryasana_): Train=218, Test=47, Valid=46, Total=311
# Class 8 (Chair_Pose_or_Utkatasana_): Train=159, Test=34, Valid=33, Total=226
# Class 9 (Child_Pose_or_Balasana_): Train=128, Test=25, Valid=24, Total=177
# Class 10 (Cobra_Pose_or_Bhujangasana_): Train=405, Test=82, Valid=81, Total=568
# Class 11 (Cockerel_Pose): Train=80, Test=14, Valid=13, Total=107
# Class 12 (Corpse_Pose_or_Savasana_): Train=148, Test=34, Valid=34, Total=216
# Class 13 (Cow_Face_Pose_or_Gomukhasana_): Train=155, Test=32, Valid=31, Total=218
# Class 14 (Crane_(Crow)_Pose_or_Bakasana_): Train=152, Test=29, Valid=28, Total=209
# Class 15 (Dolphin_Plank_Pose_or_Makara_Adho_Mukha_Svanasana_): Train=26, Test=4, Valid=4, Total=34
# Class 16 (Dolphin_Pose_or_Ardha_Pincha_Mayurasana_): Train=31, Test=6, Valid=5, Total=42
# Class 17 (Downward-Facing_Dog_pose_or_Adho_Mukha_Svanasana_): Train=136, Test=31, Valid=30, Total=197
# Class 18 (Eagle_Pose_or_Garudasana_): Train=163, Test=32, Valid=32, Total=227
# Class 19 (Eight-Angle_Pose_or_Astavakrasana_): Train=88, Test=20, Valid=19, Total=127
# Class 20 (Extended_Puppy_Pose_or_Uttana_Shishosana_): Train=40, Test=8, Valid=7, Total=55
# Class 21 (Extended_Revolved_Side_Angle_Pose_or_Utthita_Parsvakonasana_): Train=293, Test=65, Valid=65, Total=423
# Class 22 (Extended_Revolved_Triangle_Pose_or_Utthita_Trikonasana_): Train=286, Test=63, Valid=63, Total=412
# Class 23 (Feathered_Peacock_Pose_or_Pincha_Mayurasana_): Train=109, Test=26, Valid=26, Total=161
# Class 24 (Firefly_Pose_or_Tittibhasana_): Train=99, Test=19, Valid=18, Total=136
# Class 25 (Fish_Pose_or_Matsyasana_): Train=142, Test=30, Valid=29, Total=201
# Class 26 (Four-Limbed_Staff_Pose_or_Chaturanga_Dandasana_): Train=114, Test=26, Valid=25, Total=165
# Class 27 (Frog_Pose_or_Bhekasana): Train=81, Test=18, Valid=17, Total=116
# Class 28 (Garland_Pose_or_Malasana_): Train=124, Test=21, Valid=21, Total=166
# Class 29 (Gate_Pose_or_Parighasana_): Train=89, Test=17, Valid=17, Total=123
# Class 30 (Half_Lord_of_the_Fishes_Pose_or_Ardha_Matsyendrasana_): Train=176, Test=38, Valid=37, Total=251
# Class 31 (Half_Moon_Pose_or_Ardha_Chandrasana_): Train=143, Test=32, Valid=31, Total=206
# Class 32 (Handstand_pose_or_Adho_Mukha_Vrksasana_): Train=102, Test=23, Valid=23, Total=148
# Class 33 (Happy_Baby_Pose_or_Ananda_Balasana_): Train=76, Test=15, Valid=15, Total=106
# Class 34 (Head-to-Knee_Forward_Bend_pose_or_Janu_Sirsasana_): Train=84, Test=17, Valid=17, Total=118
# Class 35 (Heron_Pose_or_Krounchasana_): Train=75, Test=15, Valid=15, Total=105
# Class 36 (Intense_Side_Stretch_Pose_or_Parsvottanasana_): Train=90, Test=21, Valid=20, Total=131
# Class 37 (Legs-Up-the-Wall_Pose_or_Viparita_Karani_): Train=101, Test=24, Valid=24, Total=149
# Class 38 (Locust_Pose_or_Salabhasana_): Train=114, Test=24, Valid=24, Total=162
# Class 39 (Lord_of_the_Dance_Pose_or_Natarajasana_): Train=216, Test=47, Valid=46, Total=309
# Class 40 (Low_Lunge_pose_or_Anjaneyasana_): Train=142, Test=32, Valid=31, Total=205
# Class 41 (Noose_Pose_or_Pasasana_): Train=21, Test=4, Valid=4, Total=29
# Class 42 (Peacock_Pose_or_Mayurasana_): Train=63, Test=15, Valid=14, Total=92
# Class 43 (Pigeon_Pose_or_Kapotasana_): Train=14, Test=5, Valid=5, Total=24
# Class 44 (Plank_Pose_or_Kumbhakasana_): Train=39, Test=8, Valid=8, Total=55
# Class 45 (Plow_Pose_or_Halasana_): Train=130, Test=26, Valid=26, Total=182
# Class 46 (Pose_Dedicated_to_the_Sage_Koundinya_or_Eka_Pada_Koundinyanasana_I_and_II): Train=73, Test=16, Valid=15, Total=104
# Class 47 (Rajakapotasana): Train=125, Test=26, Valid=25, Total=176
# Class 48 (Reclining_Hand-to-Big-Toe_Pose_or_Supta_Padangusthasana_): Train=84, Test=17, Valid=16, Total=117
# Class 49 (Revolved_Head-to-Knee_Pose_or_Parivrtta_Janu_Sirsasana_): Train=115, Test=29, Valid=28, Total=172
# Class 50 (Scale_Pose_or_Tolasana_): Train=74, Test=17, Valid=16, Total=107
# Class 51 (Scorpion_pose_or_vrischikasana): Train=118, Test=24, Valid=23, Total=165
# Class 52 (Seated_Forward_Bend_pose_or_Paschimottanasana_): Train=141, Test=28, Valid=28, Total=197
# Class 53 (Shoulder-Pressing_Pose_or_Bhujapidasana_): Train=51, Test=11, Valid=10, Total=72
# Class 54 (Side-Reclining_Leg_Lift_pose_or_Anantasana_): Train=37, Test=7, Valid=7, Total=51
# Class 55 (Side_Crane_(Crow)_Pose_or_Parsva_Bakasana_): Train=92, Test=21, Valid=21, Total=134
# Class 56 (Side_Plank_Pose_or_Vasisthasana_): Train=173, Test=36, Valid=36, Total=245
# Class 57 (Sitting pose 1 (normal)): Train=353, Test=77, Valid=76, Total=506
# Class 58 (Split pose): Train=173, Test=36, Valid=36, Total=245
# Class 59 (Staff_Pose_or_Dandasana_): Train=44, Test=7, Valid=7, Total=58
# Class 60 (Standing_Forward_Bend_pose_or_Uttanasana_): Train=177, Test=41, Valid=41, Total=259
# Class 61 (Standing_Split_pose_or_Urdhva_Prasarita_Eka_Padasana_): Train=81, Test=15, Valid=14, Total=110
# Class 62 (Standing_big_toe_hold_pose_or_Utthita_Padangusthasana): Train=100, Test=22, Valid=21, Total=143
# Class 63 (Supported_Headstand_pose_or_Salamba_Sirsasana_): Train=162, Test=37, Valid=36, Total=235
# Class 64 (Supported_Shoulderstand_pose_or_Salamba_Sarvangasana_): Train=116, Test=27, Valid=26, Total=169
# Class 65 (Supta_Baddha_Konasana_): Train=168, Test=38, Valid=38, Total=244
# Class 66 (Supta_Virasana_Vajrasana): Train=150, Test=30, Valid=29, Total=209
# Class 67 (Tortoise_Pose): Train=49, Test=10, Valid=9, Total=68
# Class 68 (Tree_Pose_or_Vrksasana_): Train=134, Test=30, Valid=29, Total=193
# Class 69 (Upward_Bow_(Wheel)_Pose_or_Urdhva_Dhanurasana_): Train=52, Test=10, Valid=9, Total=71
# Class 70 (Upward_Facing_Two-Foot_Staff_Pose_or_Dwi_Pada_Viparita_Dandasana_): Train=22, Test=10, Valid=10, Total=42
# Class 71 (Upward_Plank_Pose_or_Purvottanasana_): Train=131, Test=25, Valid=24, Total=180
# Class 72 (Viparita_virabhadrasana_or_reverse_warrior_pose): Train=102, Test=15, Valid=15, Total=132
# Class 73 (Virasana_or_Vajrasana): Train=198, Test=42, Valid=41, Total=281
# Class 74 (Warrior_III_Pose_or_Virabhadrasana_III_): Train=117, Test=15, Valid=15, Total=147
# Class 75 (Warrior_II_Pose_or_Virabhadrasana_II_): Train=168, Test=35, Valid=34, Total=237
# Class 76 (Warrior_I_Pose_or_Virabhadrasana_I_): Train=86, Test=28, Valid=28, Total=142
# Class 77 (Wide-Angle_Seated_Forward_Bend_pose_or_Upavistha_Konasana_): Train=113, Test=27, Valid=26, Total=166
# Class 78 (Wide-Legged_Forward_Bend_pose_or_Prasarita_Padottanasana_): Train=145, Test=32, Valid=31, Total=208
# Class 79 (Wild_Thing_pose_or_Camatkarasana_): Train=103, Test=26, Valid=26, Total=155
# Class 80 (Wind_Relieving_pose_or_Pawanmuktasana): Train=95, Test=22, Valid=22, Total=139
# Class 81 (Yogic_sleep_pose): Train=28, Test=9, Valid=8, Total=45

# %%
train_counts = {cls: counts['train'] for cls, counts in class_file_counts.items()}
sorted_train_classes = sorted(train_counts.items(), key=lambda x: x[1], reverse=True)

# Select the top 10 classes with the largest amount of training data
top_classes = sorted_train_classes[:10]

# Display histograms only for the top 10 classes with the most data in the "train" split
top_class_names = [cls for cls, _ in top_classes]
file_counts = [class_file_counts[cls]['train'] for cls in top_class_names]

plt.figure(figsize=(12, 6))
plt.bar(top_class_names, file_counts, edgecolor='black', alpha=0.7)
plt.xlabel("Classes")
plt.ylabel("Number of Files (Train)")
plt.title("File Distribution in Classes with the Largest Amount of Training Data")
plt.xticks(rotation=90)  # Rotate class names for better readability
plt.tight_layout()  # Adjust layout to avoid overlap
plt.show()

print("\nNumber of training files in selected classes:")
for cls, count in zip(top_class_names, file_counts):
    print(f"{cls}: {count}")
# Out:
# Number of training files in selected classes:
# Cobra_Pose_or_Bhujangasana_: 405
# Sitting pose 1 (normal): 353
# Extended_Revolved_Side_Angle_Pose_or_Utthita_Parsvakonasana_: 293
# Extended_Revolved_Triangle_Pose_or_Utthita_Trikonasana_: 286
# Cat_Cow_Pose_or_Marjaryasana_: 218
# Lord_of_the_Dance_Pose_or_Natarajasana_: 216
# Virasana_or_Vajrasana: 198
# Boat_Pose_or_Paripurna_Navasana_: 191
# Standing_Forward_Bend_pose_or_Uttanasana_: 177
# Half_Lord_of_the_Fishes_Pose_or_Ardha_Matsyendrasana_: 176

# %% [markdown]
# # Dataset preprocessing

# %%
train_ds = tf.data.Dataset.list_files(str(dataset_path/'train/*/*.npy'), shuffle=True)

val_ds = tf.data.Dataset.list_files(str(dataset_path/'valid/*/*.npy'), shuffle=False)

test_ds = tf.data.Dataset.list_files(str(dataset_path/'test/*/*.npy'), shuffle=False)

# %%
def count_elements(dataset):
    count = 0
    for _ in dataset:
        count += 1
    return count

train_ds_count = count_elements(train_ds)
val_ds_count = count_elements(val_ds)
test_ds_count = count_elements(test_ds)

print(f"Tamanho do train_ds: {train_ds_count}")
print(f"Tamanho do val_ds: {val_ds_count}")
print(f"Tamanho do test_ds: {test_ds_count}")
# Out:
# Tamanho do train_ds: 9754
# Tamanho do val_ds: 2051
# Tamanho do test_ds: 2096

# %%
for f in train_ds.take(5):
    print(f.numpy())
# Out:
# b'kp_ds_not_aug_1/train/Cat_Cow_Pose_or_Marjaryasana_/1_447.npy'
# b'kp_ds_not_aug_1/train/Locust_Pose_or_Salabhasana_/179.npy'
# b'kp_ds_not_aug_1/train/Half_Lord_of_the_Fishes_Pose_or_Ardha_Matsyendrasana_/1_528.npy'
# b'kp_ds_not_aug_1/train/Fish_Pose_or_Matsyasana_/181.npy'
# b'kp_ds_not_aug_1/train/Supported_Headstand_pose_or_Salamba_Sirsasana_/351.npy'

# %%
class_names = np.array(sorted([item.name for item in dataset_path.glob('train/*')]))
class_names
# Out:
# array(['Akarna_Dhanurasana',
#        "Bharadvaja's_Twist_pose_or_Bharadvajasana_I_",
#        'Boat_Pose_or_Paripurna_Navasana_',
#        'Bound_Angle_Pose_or_Baddha_Konasana_', 'Bow_Pose_or_Dhanurasana_',
#        'Bridge_Pose_or_Setu_Bandha_Sarvangasana_',
#        'Camel_Pose_or_Ustrasana_', 'Cat_Cow_Pose_or_Marjaryasana_',
#        'Chair_Pose_or_Utkatasana_', 'Child_Pose_or_Balasana_',
#        'Cobra_Pose_or_Bhujangasana_', 'Cockerel_Pose',
#        'Corpse_Pose_or_Savasana_', 'Cow_Face_Pose_or_Gomukhasana_',
#        'Crane_(Crow)_Pose_or_Bakasana_',
#        'Dolphin_Plank_Pose_or_Makara_Adho_Mukha_Svanasana_',
#        'Dolphin_Pose_or_Ardha_Pincha_Mayurasana_',
#        'Downward-Facing_Dog_pose_or_Adho_Mukha_Svanasana_',
#        'Eagle_Pose_or_Garudasana_', 'Eight-Angle_Pose_or_Astavakrasana_',
#        'Extended_Puppy_Pose_or_Uttana_Shishosana_',
#        'Extended_Revolved_Side_Angle_Pose_or_Utthita_Parsvakonasana_',
#        'Extended_Revolved_Triangle_Pose_or_Utthita_Trikonasana_',
#        'Feathered_Peacock_Pose_or_Pincha_Mayurasana_',
#        'Firefly_Pose_or_Tittibhasana_', 'Fish_Pose_or_Matsyasana_',
#        'Four-Limbed_Staff_Pose_or_Chaturanga_Dandasana_',
#        'Frog_Pose_or_Bhekasana', 'Garland_Pose_or_Malasana_',
#        'Gate_Pose_or_Parighasana_',
#        'Half_Lord_of_the_Fishes_Pose_or_Ardha_Matsyendrasana_',
#        'Half_Moon_Pose_or_Ardha_Chandrasana_',
#        'Handstand_pose_or_Adho_Mukha_Vrksasana_',
#        'Happy_Baby_Pose_or_Ananda_Balasana_',
#        'Head-to-Knee_Forward_Bend_pose_or_Janu_Sirsasana_',
#        'Heron_Pose_or_Krounchasana_',
#        'Intense_Side_Stretch_Pose_or_Parsvottanasana_',
#        'Legs-Up-the-Wall_Pose_or_Viparita_Karani_',
#        'Locust_Pose_or_Salabhasana_',
#        'Lord_of_the_Dance_Pose_or_Natarajasana_',
#        'Low_Lunge_pose_or_Anjaneyasana_', 'Noose_Pose_or_Pasasana_',
#        'Peacock_Pose_or_Mayurasana_', 'Pigeon_Pose_or_Kapotasana_',
#        'Plank_Pose_or_Kumbhakasana_', 'Plow_Pose_or_Halasana_',
#        'Pose_Dedicated_to_the_Sage_Koundinya_or_Eka_Pada_Koundinyanasana_I_and_II',
#        'Rajakapotasana',
#        'Reclining_Hand-to-Big-Toe_Pose_or_Supta_Padangusthasana_',
#        'Revolved_Head-to-Knee_Pose_or_Parivrtta_Janu_Sirsasana_',
#        'Scale_Pose_or_Tolasana_', 'Scorpion_pose_or_vrischikasana',
#        'Seated_Forward_Bend_pose_or_Paschimottanasana_',
#        'Shoulder-Pressing_Pose_or_Bhujapidasana_',
#        'Side-Reclining_Leg_Lift_pose_or_Anantasana_',
#        'Side_Crane_(Crow)_Pose_or_Parsva_Bakasana_',
#        'Side_Plank_Pose_or_Vasisthasana_', 'Sitting pose 1 (normal)',
#        'Split pose', 'Staff_Pose_or_Dandasana_',
#        'Standing_Forward_Bend_pose_or_Uttanasana_',
#        'Standing_Split_pose_or_Urdhva_Prasarita_Eka_Padasana_',
#        'Standing_big_toe_hold_pose_or_Utthita_Padangusthasana',
#        'Supported_Headstand_pose_or_Salamba_Sirsasana_',
#        'Supported_Shoulderstand_pose_or_Salamba_Sarvangasana_',
#        'Supta_Baddha_Konasana_', 'Supta_Virasana_Vajrasana',
#        'Tortoise_Pose', 'Tree_Pose_or_Vrksasana_',
#        'Upward_Bow_(Wheel)_Pose_or_Urdhva_Dhanurasana_',
#        'Upward_Facing_Two-Foot_Staff_Pose_or_Dwi_Pada_Viparita_Dandasana_',
#        'Upward_Plank_Pose_or_Purvottanasana_',
#        'Viparita_virabhadrasana_or_reverse_warrior_pose',
#        'Virasana_or_Vajrasana', 'Warrior_III_Pose_or_Virabhadrasana_III_',
#        'Warrior_II_Pose_or_Virabhadrasana_II_',
#        'Warrior_I_Pose_or_Virabhadrasana_I_',
#        'Wide-Angle_Seated_Forward_Bend_pose_or_Upavistha_Konasana_',
#        'Wide-Legged_Forward_Bend_pose_or_Prasarita_Padottanasana_',
#        'Wild_Thing_pose_or_Camatkarasana_',
#        'Wind_Relieving_pose_or_Pawanmuktasana', 'Yogic_sleep_pose'],
#       dtype='<U73')

# %%
num_classes = len(class_names)
num_classes
# Out:
# 82

# %% [markdown]
# ## `tf.data` preprocessing

# %%
def get_label(file_path):
    """
    Retrieves the label (class) from the file path.
    """
    parts = tf.strings.split(file_path, os.path.sep)
    one_hot = parts[-2] == class_names
    return tf.argmax(one_hot)

def decode_npy(file_path):
    """
    Loads data from a .npy file.
    """
    # Using tf.numpy_function to load the .npy file with numpy
    def load_npy(path):
        return np.load(path.decode('utf-8')).astype(np.float32)

    # Convert the path to a tensor using numpy_function
    npy_data = tf.numpy_function(load_npy, [file_path], tf.float32)
    npy_data.set_shape([33, 4])
    return npy_data

def process_path(file_path, label=None):
    """
    Processes the file path to obtain data and labels.
    """
    label = get_label(file_path)  # Retrieve label
    data = decode_npy(file_path)  # Load data from the .npy file
    return data, label

# %%
# Dataset mapping
train_ds = train_ds.map(process_path, num_parallel_calls=tf.data.AUTOTUNE)
val_ds = val_ds.map(process_path, num_parallel_calls=tf.data.AUTOTUNE)
test_ds = test_ds.map(process_path, num_parallel_calls=tf.data.AUTOTUNE)

# %%
for input_batch, label_batch in train_ds.take(1):
    print(input_batch.shape)
    print(label_batch.numpy())
# Out:
# (33, 4)
# 7

# %%
def configure_for_performance(ds, shuffle=False):
    """
    Configures the dataset for better performance during training.
    """
    ds = ds.cache()
    if shuffle:
        ds = ds.shuffle(buffer_size=1000)
    ds = ds.batch(32)
    ds = ds.prefetch(buffer_size=tf.data.AUTOTUNE)
    return ds

# %%
train_ds = configure_for_performance(train_ds, shuffle=True)
val_ds = configure_for_performance(val_ds, shuffle=False)
test_ds = configure_for_performance(test_ds, shuffle=False)

# %% [markdown]
# # Transformer with CNN extraction

# %% [markdown]
# ## Transformer Encoder

# %%
init = HeUniform(seed=42)
reg1 = l2(1e-4)
reg2 = l2(1e-5)

# %%
@tf.keras.utils.register_keras_serializable()
class TransformerEncoder(layers.Layer):
  def __init__(self, num_heads, conv_dim, name, **kwargs):
    super(TransformerEncoder, self).__init__(name=name, **kwargs)

    self.num_heads = num_heads
    self.conv_dim = conv_dim

    self.layer_norm = layers.LayerNormalization()
    self.mha = layers.MultiHeadAttention(self.num_heads, self.conv_dim,
                                         kernel_initializer=init)
    self.conv_proj = tf.keras.Sequential([
        layers.Dense(self.conv_dim, activation='relu', kernel_regularizer=reg1, bias_regularizer=reg1, activity_regularizer=reg2),
        layers.Dense(self.conv_dim, activation='relu', kernel_regularizer=reg1, bias_regularizer=reg1, activity_regularizer=reg2),
        layers.Dense(self.conv_dim, kernel_regularizer=reg1, bias_regularizer=reg1, activity_regularizer=reg2)
    ])

  def build(self, input_shape):
    super(TransformerEncoder, self).build(input_shape)

  def call(self, inputs):
    attention_output = self.mha(query=inputs, value=inputs, key=inputs)
    proj_input = self.layer_norm(inputs + attention_output)
    proj_output = self.conv_proj(proj_input)
    return self.layer_norm(proj_input + proj_output)

  def get_config(self):
    config = super().get_config()
    config.update({
        "num_heads": self.mha.num_heads,
        "conv_dim": self.mha.key_dim,
    })
    return config

# %% [markdown]
# ## Model architecture

# %%
input_shape = (33, 4)

inputs = tf.keras.Input(shape=input_shape)
x = layers.MultiHeadAttention(num_heads=4, key_dim=16)(inputs, inputs)
x = inputs + x
x = layers.Conv1D(filters=80, kernel_size=5, padding="same")(x)
x = layers.BatchNormalization()(x)
x = layers.Activation('relu')(x)
x = layers.Conv1D(filters=48, kernel_size=5, padding="same", kernel_regularizer=reg1)(x)
x = layers.BatchNormalization()(x)
x = layers.Activation('relu')(x)
x = layers.Dropout(0.25)(x)
x = layers.Conv1D(filters=16, kernel_size=5, padding="same", kernel_regularizer=reg1, bias_regularizer=reg1, activity_regularizer=reg2)(x)
x = layers.BatchNormalization()(x)
x = layers.Activation('relu')(x)
x = TransformerEncoder(num_heads=4, conv_dim=16, name='transformer_encoder')(x)
x = layers.Flatten()(x)
x = layers.Dense(88, activation='relu', kernel_regularizer=reg1, bias_regularizer=reg1, activity_regularizer=reg2)(x)
x = layers.Dropout(0.5)(x)
outputs = layers.Dense(num_classes, activation='softmax')(x)

transformer = keras.Model(inputs=inputs, outputs=outputs)

# %%
transformer.summary()
# Out:
# Model: "functional_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)              ┃ Output Shape           ┃        Param # ┃ Connected to           ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)  │ (None, 33, 4)          │              0 │ -                      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ multi_head_attention      │ (None, 33, 4)          │          1,220 │ input_layer[0][0],     │
# │ (MultiHeadAttention)      │                        │                │ input_layer[0][0]      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ add (Add)                 │ (None, 33, 4)          │              0 │ input_layer[0][0],     │
# │                           │                        │                │ multi_head_attention[… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv1d (Conv1D)           │ (None, 33, 80)         │          1,680 │ add[0][0]              │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization       │ (None, 33, 80)         │            320 │ conv1d[0][0]           │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ activation (Activation)   │ (None, 33, 80)         │              0 │ batch_normalization[0… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv1d_1 (Conv1D)         │ (None, 33, 48)         │         19,248 │ activation[0][0]       │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_1     │ (None, 33, 48)         │            192 │ conv1d_1[0][0]         │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ activation_1 (Activation) │ (None, 33, 48)         │              0 │ batch_normalization_1… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dropout_1 (Dropout)       │ (None, 33, 48)         │              0 │ activation_1[0][0]     │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv1d_2 (Conv1D)         │ (None, 33, 16)         │          3,856 │ dropout_1[0][0]        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_2     │ (None, 33, 16)         │             64 │ conv1d_2[0][0]         │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ activation_2 (Activation) │ (None, 33, 16)         │              0 │ batch_normalization_2… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ transformer_encoder       │ (None, 33, 16)         │          5,152 │ activation_2[0][0]     │
# │ (TransformerEncoder)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ flatten (Flatten)         │ (None, 528)            │              0 │ transformer_encoder[0… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_3 (Dense)           │ (None, 88)             │         46,552 │ flatten[0][0]          │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dropout_3 (Dropout)       │ (None, 88)             │              0 │ dense_3[0][0]          │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_4 (Dense)           │ (None, 82)             │          7,298 │ dropout_3[0][0]        │
# └───────────────────────────┴────────────────────────┴────────────────┴────────────────────────┘
#  Total params: 85,582 (334.30 KB)
#  Trainable params: 85,294 (333.18 KB)
#  Non-trainable params: 288 (1.12 KB)

# %% [markdown]
# ## Model training

# %%
def scheduler(epoch, lr):
  if epoch < 20:
    return lr
  else:
    return lr * float(tf.math.exp(-0.1))

callbacks = [
    ModelCheckpoint(filepath='kp_ds_not_aug_1_model_1_tranformer_cnn.keras',
                    save_best_only=True,
                    monitor='val_accuracy',
                    verbose=1),
    LearningRateScheduler(scheduler),
    EarlyStopping(monitor='val_accuracy', patience=15, restore_best_weights=True)
]

# %%
transformer.compile(optimizer=tf.keras.optimizers.AdamW(learning_rate=1e-3),
            loss=tf.keras.losses.SparseCategoricalCrossentropy(),
            metrics=['accuracy'])

# %%
history = transformer.fit(
    train_ds,
    epochs=150,
    validation_data=val_ds,
    callbacks=callbacks)
# Out:
# Epoch 1/150
# 305/305 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.1240 - loss: 4.0771
# Epoch 1: val_accuracy improved from -inf to 0.32618, saving model to kp_ds_not_aug_1_model_1_tranformer_cnn.keras
# 305/305 ━━━━━━━━━━━━━━━━━━━━ 33s 57ms/step - accuracy: 0.1244 - loss: 4.0750 - val_accuracy: 0.3262 - val_loss: 2.7812 - learning_rate: 0.0010
# Epoch 2/150
# 305/305 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.4632 - loss: 2.1917
# Epoch 2: val_accuracy improved from 0.32618 to 0.69868, saving model to kp_ds_not_aug_1_model_1_tranformer_cnn.keras
# 305/305 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.4633 - loss: 2.1911 - val_accuracy: 0.6987 - val_loss: 1.1775 - learning_rate: 0.0010
# Epoch 3/150
# 304/305 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6053 - loss: 1.5897
# Epoch 3: val_accuracy improved from 0.69868 to 0.78157, saving model to kp_ds_not_aug_1_model_1_tranformer_cnn.keras
# 305/305 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.6054 - loss: 1.5893 - val_accuracy: 0.7816 - val_loss: 0.9911 - learning_rate: 0.0010
# Epoch 4/150
# 300/305 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6673 - loss: 1.3597
# Epoch 4: val_accuracy improved from 0.78157 to 0.80205, saving model to kp_ds_not_aug_1_model_1_tranformer_cnn.keras
# 305/305 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.6674 - loss: 1.3591 - val_accuracy: 0.8020 - val_loss: 0.9095 - learning_rate: 0.0010
# Epoch 5/150
# 291/305 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6959 - loss: 1.2221
# Epoch 5: val_accuracy did not improve from 0.80205
# 305/305 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.6960 - loss: 1.2214 - val_accuracy: 0.7903 - val_loss: 0.8950 - learning_rate: 0.0010
# Epoch 6/150
# 292/305 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7198 - loss: 1.1301
# Epoch 6: val_accuracy did not improve from 0.80205
# 305/305 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.7200 - loss: 1.1296 - val_accuracy: 0.8016 - val_loss: 0.8863 - learning_rate: 0.0010
# Epoch 7/150
# 304/305 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7466 - loss: 1.0499
# Epoch 7: val_accuracy improved from 0.80205 to 0.82545, saving model to kp_ds_not_aug_1_model_1_tranformer_cnn.keras
# 305/305 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.7465 - loss: 1.0499 - val_accuracy: 0.8255 - val_loss: 0.8203 - learning_rate: 0.0010
# Epoch 8/150
# 290/305 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7575 - loss: 0.9828
# Epoch 8: val_accuracy improved from 0.82545 to 0.83276, saving model to kp_ds_not_aug_1_model_1_tranformer_cnn.keras
# 305/305 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.7576 - loss: 0.9828 - val_accuracy: 0.8328 - val_loss: 0.7593 - learning_rate: 0.0010
# Epoch 9/150
# 305/305 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7696 - loss: 0.9508
# Epoch 9: val_accuracy did not improve from 0.83276
# 305/305 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7697 - loss: 0.9508 - val_accuracy: 0.8274 - val_loss: 0.7630 - learning_rate: 0.0010
# Epoch 10/150
# 290/305 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7819 - loss: 0.9040
# Epoch 10: val_accuracy improved from 0.83276 to 0.83959, saving model to kp_ds_not_aug_1_model_1_tranformer_cnn.keras
# 305/305 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.7819 - loss: 0.9043 - val_accuracy: 0.8396 - val_loss: 0.7209 - learning_rate: 0.0010
# Epoch 11/150
# 301/305 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7822 - loss: 0.9017
# Epoch 11: val_accuracy improved from 0.83959 to 0.84252, saving model to kp_ds_not_aug_1_model_1_tranformer_cnn.keras
# 305/305 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.7823 - loss: 0.9014 - val_accuracy: 0.8425 - val_loss: 0.7095 - learning_rate: 0.0010
# Epoch 12/150
# 296/305 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7975 - loss: 0.8530
# Epoch 12: val_accuracy did not improve from 0.84252
# 305/305 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7975 - loss: 0.8528 - val_accuracy: 0.8352 - val_loss: 0.7231 - learning_rate: 0.0010
# Epoch 13/150
# 304/305 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7950 - loss: 0.8465
# Epoch 13: val_accuracy improved from 0.84252 to 0.85958, saving model to kp_ds_not_aug_1_model_1_tranformer_cnn.keras
# 305/305 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.7950 - loss: 0.8465 - val_accuracy: 0.8596 - val_loss: 0.6572 - learning_rate: 0.0010
# Epoch 14/150
# 289/305 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8077 - loss: 0.8156
# Epoch 14: val_accuracy did not improve from 0.85958
# 305/305 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8075 - loss: 0.8158 - val_accuracy: 0.8498 - val_loss: 0.6848 - learning_rate: 0.0010
# Epoch 15/150
# 290/305 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8116 - loss: 0.7861
# Epoch 15: val_accuracy improved from 0.85958 to 0.86251, saving model to kp_ds_not_aug_1_model_1_tranformer_cnn.keras
# 305/305 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8115 - loss: 0.7868 - val_accuracy: 0.8625 - val_loss: 0.6778 - learning_rate: 0.0010
# Epoch 16/150
# 301/305 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8109 - loss: 0.7748
# Epoch 16: val_accuracy did not improve from 0.86251
# 305/305 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8109 - loss: 0.7748 - val_accuracy: 0.8518 - val_loss: 0.7061 - learning_rate: 0.0010
# Epoch 17/150
# 290/305 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8224 - loss: 0.7658
# Epoch 17: val_accuracy improved from 0.86251 to 0.86299, saving model to kp_ds_not_aug_1_model_1_tranformer_cnn.keras
# 305/305 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8225 - loss: 0.7656 - val_accuracy: 0.8630 - val_loss: 0.6768 - learning_rate: 0.0010
# Epoch 18/150
# 294/305 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8188 - loss: 0.7488
# Epoch 18: val_accuracy did not improve from 0.86299
# 305/305 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8186 - loss: 0.7491 - val_accuracy: 0.8562 - val_loss: 0.6786 - learning_rate: 0.0010
# Epoch 19/150
# 290/305 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8284 - loss: 0.7277
# Epoch 19: val_accuracy did not improve from 0.86299
# 305/305 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8284 - loss: 0.7277 - val_accuracy: 0.8576 - val_loss: 0.6919 - learning_rate: 0.0010
# Epoch 20/150
# 290/305 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8219 - loss: 0.7338
# Epoch 20: val_accuracy improved from 0.86299 to 0.86543, saving model to kp_ds_not_aug_1_model_1_tranformer_cnn.keras
# 305/305 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8221 - loss: 0.7332 - val_accuracy: 0.8654 - val_loss: 0.6516 - learning_rate: 0.0010
# Epoch 21/150
# 301/305 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8419 - loss: 0.6849
# Epoch 21: val_accuracy did not improve from 0.86543
# 305/305 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8419 - loss: 0.6850 - val_accuracy: 0.8635 - val_loss: 0.6421 - learning_rate: 9.0484e-04
# Epoch 22/150
# 304/305 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8423 - loss: 0.6691
# Epoch 22: val_accuracy improved from 0.86543 to 0.86836, saving model to kp_ds_not_aug_1_model_1_tranformer_cnn.keras
# 305/305 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8423 - loss: 0.6690 - val_accuracy: 0.8684 - val_loss: 0.6473 - learning_rate: 8.1873e-04
# Epoch 23/150
# 303/305 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8590 - loss: 0.6209
# Epoch 23: val_accuracy improved from 0.86836 to 0.87372, saving model to kp_ds_not_aug_1_model_1_tranformer_cnn.keras
# 305/305 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8589 - loss: 0.6210 - val_accuracy: 0.8737 - val_loss: 0.6159 - learning_rate: 7.4082e-04
# Epoch 24/150
# 293/305 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8488 - loss: 0.6363
# Epoch 24: val_accuracy improved from 0.87372 to 0.87762, saving model to kp_ds_not_aug_1_model_1_tranformer_cnn.keras
# 305/305 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8489 - loss: 0.6361 - val_accuracy: 0.8776 - val_loss: 0.6308 - learning_rate: 6.7032e-04
# Epoch 25/150
# 302/305 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8578 - loss: 0.6071
# Epoch 25: val_accuracy did not improve from 0.87762
# 305/305 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8578 - loss: 0.6071 - val_accuracy: 0.8752 - val_loss: 0.6147 - learning_rate: 6.0653e-04
# Epoch 26/150
# 302/305 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8699 - loss: 0.5744
# Epoch 26: val_accuracy improved from 0.87762 to 0.88103, saving model to kp_ds_not_aug_1_model_1_tranformer_cnn.keras
# 305/305 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8699 - loss: 0.5744 - val_accuracy: 0.8810 - val_loss: 0.6252 - learning_rate: 5.4881e-04
# Epoch 27/150
# 303/305 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8701 - loss: 0.5728
# Epoch 27: val_accuracy did not improve from 0.88103
# 305/305 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8701 - loss: 0.5728 - val_accuracy: 0.8693 - val_loss: 0.6292 - learning_rate: 4.9659e-04
# Epoch 28/150
# 301/305 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8742 - loss: 0.5504
# Epoch 28: val_accuracy did not improve from 0.88103
# 305/305 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8742 - loss: 0.5505 - val_accuracy: 0.8781 - val_loss: 0.6184 - learning_rate: 4.4933e-04
# Epoch 29/150
# 298/305 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8721 - loss: 0.5689
# Epoch 29: val_accuracy improved from 0.88103 to 0.88493, saving model to kp_ds_not_aug_1_model_1_tranformer_cnn.keras
# 305/305 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8721 - loss: 0.5684 - val_accuracy: 0.8849 - val_loss: 0.5999 - learning_rate: 4.0657e-04
# Epoch 30/150
# 303/305 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8774 - loss: 0.5418
# Epoch 30: val_accuracy did not improve from 0.88493
# 305/305 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8774 - loss: 0.5418 - val_accuracy: 0.8835 - val_loss: 0.6118 - learning_rate: 3.6788e-04
# Epoch 31/150
# 304/305 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8841 - loss: 0.5280
# Epoch 31: val_accuracy did not improve from 0.88493
# 305/305 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8840 - loss: 0.5280 - val_accuracy: 0.8825 - val_loss: 0.6215 - learning_rate: 3.3287e-04
# Epoch 32/150
# 301/305 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8826 - loss: 0.5300
# Epoch 32: val_accuracy improved from 0.88493 to 0.88883, saving model to kp_ds_not_aug_1_model_1_tranformer_cnn.keras
# 305/305 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8826 - loss: 0.5298 - val_accuracy: 0.8888 - val_loss: 0.5956 - learning_rate: 3.0119e-04
# Epoch 33/150
# 300/305 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8846 - loss: 0.4907
# Epoch 33: val_accuracy did not improve from 0.88883
# 305/305 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8846 - loss: 0.4908 - val_accuracy: 0.8849 - val_loss: 0.6083 - learning_rate: 2.7253e-04
# Epoch 34/150
# 304/305 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8930 - loss: 0.4895
# Epoch 34: val_accuracy did not improve from 0.88883
# 305/305 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8930 - loss: 0.4895 - val_accuracy: 0.8825 - val_loss: 0.6116 - learning_rate: 2.4660e-04
# Epoch 35/150
# 297/305 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8824 - loss: 0.4952
# Epoch 35: val_accuracy did not improve from 0.88883
# 305/305 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8826 - loss: 0.4948 - val_accuracy: 0.8825 - val_loss: 0.6149 - learning_rate: 2.2313e-04
# Epoch 36/150
# 295/305 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8936 - loss: 0.4841
# Epoch 36: val_accuracy did not improve from 0.88883
# 305/305 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8935 - loss: 0.4838 - val_accuracy: 0.8883 - val_loss: 0.6061 - learning_rate: 2.0190e-04
# Epoch 37/150
# 304/305 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8946 - loss: 0.4672
# Epoch 37: val_accuracy did not improve from 0.88883
# 305/305 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8946 - loss: 0.4672 - val_accuracy: 0.8849 - val_loss: 0.6076 - learning_rate: 1.8268e-04
# Epoch 38/150
# 298/305 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8919 - loss: 0.4769
# Epoch 38: val_accuracy did not improve from 0.88883
# 305/305 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8920 - loss: 0.4768 - val_accuracy: 0.8879 - val_loss: 0.6010 - learning_rate: 1.6530e-04
# Epoch 39/150
# 299/305 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8996 - loss: 0.4557
# Epoch 39: val_accuracy did not improve from 0.88883
# 305/305 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8996 - loss: 0.4557 - val_accuracy: 0.8879 - val_loss: 0.5992 - learning_rate: 1.4957e-04
# Epoch 40/150
# 294/305 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8945 - loss: 0.4615
# Epoch 40: val_accuracy did not improve from 0.88883
# 305/305 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8946 - loss: 0.4613 - val_accuracy: 0.8859 - val_loss: 0.5970 - learning_rate: 1.3534e-04
# Epoch 41/150
# 305/305 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9013 - loss: 0.4526
# Epoch 41: val_accuracy improved from 0.88883 to 0.88932, saving model to kp_ds_not_aug_1_model_1_tranformer_cnn.keras
# 305/305 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9013 - loss: 0.4526 - val_accuracy: 0.8893 - val_loss: 0.5970 - learning_rate: 1.2246e-04
# Epoch 42/150
# 304/305 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9029 - loss: 0.4450
# Epoch 42: val_accuracy improved from 0.88932 to 0.89225, saving model to kp_ds_not_aug_1_model_1_tranformer_cnn.keras
# 305/305 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9029 - loss: 0.4450 - val_accuracy: 0.8922 - val_loss: 0.5965 - learning_rate: 1.1080e-04
# Epoch 43/150
# 294/305 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9010 - loss: 0.4375
# Epoch 43: val_accuracy did not improve from 0.89225
# 305/305 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9010 - loss: 0.4376 - val_accuracy: 0.8908 - val_loss: 0.5964 - learning_rate: 1.0026e-04
# Epoch 44/150
# 292/305 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9049 - loss: 0.4403
# Epoch 44: val_accuracy improved from 0.89225 to 0.89371, saving model to kp_ds_not_aug_1_model_1_tranformer_cnn.keras
# 305/305 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9048 - loss: 0.4403 - val_accuracy: 0.8937 - val_loss: 0.5912 - learning_rate: 9.0718e-05
# Epoch 45/150
# 305/305 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9024 - loss: 0.4368
# Epoch 45: val_accuracy did not improve from 0.89371
# 305/305 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9024 - loss: 0.4368 - val_accuracy: 0.8903 - val_loss: 0.5970 - learning_rate: 8.2085e-05
# Epoch 46/150
# 297/305 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8998 - loss: 0.4374
# Epoch 46: val_accuracy did not improve from 0.89371
# 305/305 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8999 - loss: 0.4372 - val_accuracy: 0.8879 - val_loss: 0.5955 - learning_rate: 7.4273e-05
# Epoch 47/150
# 302/305 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9044 - loss: 0.4324
# Epoch 47: val_accuracy did not improve from 0.89371
# 305/305 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9043 - loss: 0.4325 - val_accuracy: 0.8937 - val_loss: 0.5911 - learning_rate: 6.7205e-05
# Epoch 48/150
# 300/305 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9026 - loss: 0.4448
# Epoch 48: val_accuracy did not improve from 0.89371
# 305/305 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9027 - loss: 0.4446 - val_accuracy: 0.8898 - val_loss: 0.5945 - learning_rate: 6.0810e-05
# Epoch 49/150
# 299/305 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9077 - loss: 0.4278
# Epoch 49: val_accuracy did not improve from 0.89371
# 305/305 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9077 - loss: 0.4279 - val_accuracy: 0.8903 - val_loss: 0.5963 - learning_rate: 5.5023e-05
# Epoch 50/150
# 299/305 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9050 - loss: 0.4283
# Epoch 50: val_accuracy did not improve from 0.89371
# 305/305 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9050 - loss: 0.4282 - val_accuracy: 0.8922 - val_loss: 0.5962 - learning_rate: 4.9787e-05
# Epoch 51/150
# 294/305 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9085 - loss: 0.4353
# Epoch 51: val_accuracy did not improve from 0.89371
# 305/305 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9085 - loss: 0.4347 - val_accuracy: 0.8903 - val_loss: 0.5933 - learning_rate: 4.5049e-05
# Epoch 52/150
# 294/305 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9006 - loss: 0.4388
# Epoch 52: val_accuracy did not improve from 0.89371
# 305/305 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9007 - loss: 0.4386 - val_accuracy: 0.8922 - val_loss: 0.5943 - learning_rate: 4.0762e-05
# Epoch 53/150
# 295/305 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9079 - loss: 0.4173
# Epoch 53: val_accuracy did not improve from 0.89371
# 305/305 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9078 - loss: 0.4174 - val_accuracy: 0.8922 - val_loss: 0.5964 - learning_rate: 3.6883e-05
# Epoch 54/150
# 299/305 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9110 - loss: 0.4199
# Epoch 54: val_accuracy did not improve from 0.89371
# 305/305 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9110 - loss: 0.4198 - val_accuracy: 0.8922 - val_loss: 0.5951 - learning_rate: 3.3373e-05
# Epoch 55/150
# 299/305 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9085 - loss: 0.4187
# Epoch 55: val_accuracy did not improve from 0.89371
# 305/305 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9085 - loss: 0.4187 - val_accuracy: 0.8932 - val_loss: 0.5925 - learning_rate: 3.0197e-05
# Epoch 56/150
# 299/305 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9063 - loss: 0.4262
# Epoch 56: val_accuracy did not improve from 0.89371
# 305/305 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9063 - loss: 0.4261 - val_accuracy: 0.8922 - val_loss: 0.5937 - learning_rate: 2.7324e-05
# Epoch 57/150
# 298/305 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9067 - loss: 0.4270
# Epoch 57: val_accuracy did not improve from 0.89371
# 305/305 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9067 - loss: 0.4268 - val_accuracy: 0.8918 - val_loss: 0.5947 - learning_rate: 2.4723e-05
# Epoch 58/150
# 297/305 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9106 - loss: 0.4114
# Epoch 58: val_accuracy did not improve from 0.89371
# 305/305 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9105 - loss: 0.4114 - val_accuracy: 0.8913 - val_loss: 0.5955 - learning_rate: 2.2371e-05
# Epoch 59/150
# 301/305 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9050 - loss: 0.4315
# Epoch 59: val_accuracy did not improve from 0.89371
# 305/305 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9050 - loss: 0.4315 - val_accuracy: 0.8903 - val_loss: 0.5929 - learning_rate: 2.0242e-05

# %% [markdown]
# ## Model metrics

# %%
model = load_model("kp_ds_not_aug_1_model_1_tranformer_cnn.keras",
                   custom_objects={"TransformerEnconder": TransformerEncoder})

print("Average loss and accuracy during training:")
print(f"loss: {np.average(history.history['loss']):.4f} - accuracy: {np.average(history.history['accuracy']) * 100:.2f}%")

print("Model validation:")
scores = model.evaluate(val_ds, verbose=0)
print(f'loss: {scores[0]:.4f} - accuracy: {scores[1]* 100:.2f}%')

plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model accuracy during training')
plt.ylabel('Accuracy')
plt.xlabel('Epochs')
plt.legend(['Train.', 'Valid.'], loc='lower right')
plt.ylim(0.5, 1.0)
plt.show()

print("\n")

plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss during training')
plt.ylabel('Loss')
plt.xlabel('Epochs')
plt.legend(['Train.', 'Valid.'], loc='upper right')
plt.show()
# Out:
# Average loss and accuracy during training:
# loss: 0.7029 - accuracy: 83.55%
# Model validation:
# loss: 0.5912 - accuracy: 89.37%

# %%
scores = model.evaluate(test_ds, verbose=0)
print("Model testing:")
print(f'loss: {scores[0]:.4f} - accuracy: {scores[1]* 100:.2f}%')
# Out:
# Model testing:
# loss: 0.5618 - accuracy: 88.88%

# %%
mapped_class_names = [class_name_map[cls] for cls in sorted_class_names]  # List of mapped class names

y_pred = np.argmax(model.predict(test_ds), axis=1)  # Get predictions based on probabilities
y_true = np.concatenate([label.numpy() for kp, label in test_ds], axis=0)  # Get true labels
# Out:
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step

# %%
# Confusion matrix plot
cm = confusion_matrix(y_true, y_pred)
plt.figure(figsize=(40, 40))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues',
            xticklabels=mapped_class_names,
            yticklabels=mapped_class_names)
plt.xlabel('Predicted')
plt.ylabel('True')
plt.title('Confusion Matrix')
plt.show()

# %%
# Classification report
report = classification_report(y_true, y_pred, target_names=mapped_class_names, output_dict=True)
report_df = pd.DataFrame(report)
report_df.to_csv("kp_ds_not_aug_1_report_transformer.csv", index=True)
report_df
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#             Class 0    Class 1    Class 2   Class 3    Class 4    Class 5  \
# precision  0.857143   0.583333   0.930233   0.90625   0.909091   0.892857
# recall     0.750000   0.700000   0.975610   0.90625   0.952381   1.000000
# f1-score   0.800000   0.636364   0.952381   0.90625   0.930233   0.943396
# support    8.000000  10.000000  41.000000  32.00000  21.000000  25.000000
#
#              Class 6  Class 7    Class 8    Class 9  ...  Class 75   Class 76  \
# precision   0.878788      1.0   1.000000   0.916667  ...       1.0   1.000000
# recall      0.906250      1.0   0.882353   0.880000  ...       1.0   0.785714
# f1-score    0.892308      1.0   0.937500   0.897959  ...       1.0   0.880000
# support    32.000000     47.0  34.000000  25.000000  ...      35.0  28.000000
#
#             Class 77   Class 78   Class 79   Class 80  Class 81  accuracy  \
# precision   0.576923   0.931034   0.880000   0.909091  1.000000  0.888836
# recall      0.555556   0.843750   0.846154   0.909091  0.888889  0.888836
# f1-score    0.566038   0.885246   0.862745   0.909091  0.941176  0.888836
# support    27.000000  32.000000  26.000000  22.000000  9.000000  0.888836
#
#              macro avg  weighted avg
# precision     0.873497      0.892078
# recall        0.862620      0.888836
# f1-score      0.864524      0.888152
# support    2096.000000   2096.000000
#
# [4 rows x 85 columns]
